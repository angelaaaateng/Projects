# %% [markdown]
# ## Recommender System - Marketplace Matching
#
# In this notebook, we will:
# - Clean textual data from user-input verbatim posts
# - Use a Word2Vec model to calculate document similarities
# - Sort the most similar user input to our training data in order to recommend similar products
# - Save this model in a format that allows us to refresh the testing data
#
# The goal of this project is to create a recommender system to help Pangeans find the right "project" for them, given their profile information. Here, we are using legacy data that is from Pangea V2, when Pangeans were allowed to post services and requests, as well as purchase items on the platform. We are using the User-Inputted Titles to suggest similar services, or in V3, similar "projects".

# %% [markdown]
# ### (1) Data Collection, Preprocessing, and Exploratory Analysis

# %%
#Importing Libraries
import numpy as np
import pandas as pd

import sys
from pandas import DataFrame

import json
from pandas.io.json import json_normalize
import csv

import matplotlib.pyplot as plt
# %matplotlib inline 
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

from gensim import corpora
from collections import defaultdict
from pprint import pprint

from gensim.models.word2vec import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile

from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.test.utils import common_texts

import re
from sklearn.feature_extraction.text import CountVectorizer

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
nltk.download('stopwords') ###

import gensim 
from gensim.models import KeyedVectors
import gensim.downloader as api

from operator import itemgetter, attrgetter

from gensim.models.doc2vec import Doc2Vec

import os, sys

from operator import add

from sklearn.preprocessing import normalize

import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from adjustText import adjust_text

from sklearn.manifold import TSNE

import pickle

import json
from pprint import pprint
from pandas.io.json import json_normalize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/angelateng/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def vectorize_and_store_existing_titles():
    
    raw = pd.read_csv("allPostData.csv", header=0);
    
    #we can replace this with a filepath in the future
    titles = raw['title'];
    post_titles = [title for title in titles];
    tokens = [[word for word in title.lower().split()] for title in post_titles];
    
    clean_words = [[word for word in title if word.isalpha()] for title in tokens];
    stoplist = set(stopwords.words('english'));
    
    titles_nostopwords = [[word for word in title if word not in stoplist] for title in clean_words];   
    
    model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary = True); 
    filtered_word_list = [[word for word in title if word in model.vocab] for title in titles_nostopwords];
    
    title_vectors = {}
    for title in filtered_word_list: 
        word_vecs = [model[word] for word in title]
        if len(word_vecs) == 0:
            title_vec = [np.zeros(300)]
        else: 
            title_vec = normalize(sum(word_vecs).reshape(1, -1))
        title_vectors[" ".join(title)] = title_vec[0]
    #do we want to print out the original titles? how to do this?
    vectorized_titles = pd.DataFrame.from_dict(title_vectors)
    
    #can also replace filepath in the future
    vectorized_titles.to_pickle("/Users/angelateng/Dropbox/SharpestMinds/vectorized_titles.pkl")
    return(vectorized_titles)

#vectorize_and_store_existing_titles()

# %%
#pd.read_pickle("/Users/angelateng/Dropbox/SharpestMinds/vectorized_titles.pkl")
#sanity check

# %%
import json
from pprint import pprint

with open('allPostData.json') as fresh_data:
    user_post = json.load(fresh_data)

pprint(user_post)
# Out:
# [{'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '158',
#                              'state': 'RI',
#                              'street': 'University Ave',
#                              'zip_code': '02906'},
#               'formatted': '158 University Ave, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Cooking',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1505340466,
#                  'timezone': '+00:00'},
#   'description': "I'm trying to broaden the repertoire of culinary dishes I "
#                  "can make. Please help! I'm surviving on chicken and pasta "
#                  "rn... I'll buy the ingredients.",
#   'id': '-Kty6gXaY-_wgIheV3LS',
#   'last_modified': '2018-09-07T23:08:39.964Z',
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3877064, 41.8342705],
#                'type': 'Point'},
#   'owner_id': 'RHCWoC5WnSTXi0JWJadv18ejPwy1',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'request',
#   'price': 25,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Teach Me How To Cook!',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '157',
#                              'state': 'RI',
#                              'street': 'University Ave',
#                              'zip_code': '02906'},
#               'formatted': '157 University Ave, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Instructor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1505344715,
#                  'timezone': '+00:00'},
#   'description': "I teach you how to ride. It's an incredibly fun and "
#                  'efficient way to get around College Hill. ',
#   'id': '-KtyOIMgKr_jobuImNpl',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361704.643,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.387621, 41.83399],
#                'type': 'Point'},
#   'owner_id': 'zrbigYwCTzggBURdm89fNLstvBy2',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 15,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Long Boarding Lessons',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '233',
#                              'state': 'RI',
#                              'street': 'Hope St',
#                              'zip_code': '02906'},
#               'formatted': '233 Hope St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Instructor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1505495104,
#                  'timezone': '+00:00'},
#   'description': 'Looking for someone to motivate and guide me in my workouts',
#   'id': '-Ku6LzTUtRnQrFmuQXD5',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361720.29,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3985902, 41.8301016],
#                'type': 'Point'},
#   'owner_id': 'zrbigYwCTzggBURdm89fNLstvBy2',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'request',
#   'price': 15,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Personal Trainer',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '152',
#                              'state': 'RI',
#                              'street': 'University Ave',
#                              'zip_code': '02906'},
#               'formatted': '152 University Ave, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Instructor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1505344526,
#                  'timezone': '+00:00'},
#   'description': 'I have 10 years experience editing videos using final cut. '
#                  "I'll give you a 60 min power lesson in how to cut together "
#                  'tasteful, professional videos to share with your friends. ',
#   'id': '-KtyN_C-Ed8K9derThYz',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361704.337,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.387947, 41.834235],
#                'type': 'Point'},
#   'owner_id': 'zrbigYwCTzggBURdm89fNLstvBy2',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 15,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Final Cut Pro Lesson',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '184',
#                              'premise': 'Prince Engineering Laboratory',
#                              'state': 'RI',
#                              'street': 'Hope St',
#                              'zip_code': '02912'},
#               'formatted': 'Prince Engineering Laboratory, 184 Hope St, '
#                            'Providence, RI 02912, USA'},
#   'archived_status': 'live',
#   'category': 'Instructor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1506627363,
#                  'timezone': '+00:00'},
#   'description': "Let me help you build a resume. I've worked every job you "
#                  'can think of from investment banking-to corporate insurance- '
#                  "to working for an entertainment studio. I've learned what "
#                  "works and what doesn't let me help you out. ",
#   'id': '-Kv9qCmjEZ69RMnEi-xF',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361705.276,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.398302, 41.8268574],
#                'type': 'Point'},
#   'owner_id': '2cAi0NSxlFVDlvRuHWxstNAMX5B2',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 15,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Resume Building',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '157',
#                              'state': 'RI',
#                              'street': 'University Ave',
#                              'zip_code': '02906'},
#               'formatted': '157 University Ave, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Other',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1505344592,
#                  'timezone': '+00:00'},
#   'description': 'Everyday is an opportunity to do something incredible. If '
#                  "you're not energized, you deserve to be. ",
#   'id': '-KtyNpMTtIYc0CI7kwGb',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361704.474,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.387621, 41.83399],
#                'type': 'Point'},
#   'owner_id': 'zrbigYwCTzggBURdm89fNLstvBy2',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price_type': 'free',
#   'status': 'legacy',
#   'title': 'Motivational Pep Talk',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Columbus',
#                              'country': 'US',
#                              'county': 'Franklin County',
#                              'number': '7',
#                              'state': 'OH',
#                              'street': 'Easton Oval',
#                              'zip_code': '43219'},
#               'formatted': '7 Easton Oval, Columbus, OH 43219, USA'},
#   'archived_status': 'live',
#   'category': 'Other',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1506674858,
#                  'timezone': '+00:00'},
#   'description': "I've completed 400+ job applications over the past year in "
#                  'various industries including banking, consulting, marketing, '
#                  "startups, and  business-tech. I've also worked at CareerLAB. "
#                  "I'd love to help anyone who wants advice!",
#   'id': '-KvCfO8xUHcm5Ui_G6XI',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361705.468,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-82.9065344, 40.0424984],
#                'type': 'Point'},
#   'owner_id': '8nhkCkLxlmSNAuNgVW6y767p8uH3',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 2,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Resume + Cover Letter ',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '184',
#                              'premise': 'Prince Engineering Laboratory',
#                              'state': 'RI',
#                              'street': 'Hope St',
#                              'zip_code': '02912'},
#               'formatted': 'Prince Engineering Laboratory, 184 Hope St, '
#                            'Providence, RI 02912, USA'},
#   'archived_status': 'live',
#   'category': 'ArtsAndCrafts',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1510770434,
#                  'timezone': '+00:00'},
#   'description': 'Handmade (by me!) paracord bracelet, similar to the one Max '
#                  'wears in "Mad Max." The Bracelet is adjustable and easy to '
#                  'take on and off!',
#   'id': '-KuLiFrHGd94HJyiCxqJ',
#   'last_modified': '2018-09-07T23:08:16.999Z',
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.398302, 41.8268574],
#                'type': 'Point'},
#   'owner_id': 'RHCWoC5WnSTXi0JWJadv18ejPwy1',
#   'payment_type': 'fixed',
#   'photos': ['1532481234728'],
#   'post_type': 'offering',
#   'price': 4,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Paracord Bracelet',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '1',
#                              'state': 'RI',
#                              'street': 'Prospect St',
#                              'zip_code': '02912'},
#               'formatted': '1 Prospect St, Providence, RI 02912, USA'},
#   'archived_status': 'live',
#   'category': 'Other',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1505487803,
#                  'timezone': '+00:00'},
#   'description': "I'll help you with shooting, editing, sound mixing, whatever "
#                  'it takes to turn your visual dreams into reality!',
#   'id': '-Ku5v7rMM89IOn7jHRtP',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361704.858,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.4038127, 41.8261839],
#                'type': 'Point'},
#   'owner_id': 'uGQ1ywtBJlbWpnMs7nibLtbV6v23',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 20,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Video Production ',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Columbus',
#                              'country': 'US',
#                              'county': 'Franklin County',
#                              'number': '7',
#                              'state': 'OH',
#                              'street': 'Easton Oval',
#                              'zip_code': '43219'},
#               'formatted': '7 Easton Oval, Columbus, OH 43219, USA'},
#   'archived_status': 'live',
#   'category': 'Instructor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1506675014,
#                  'timezone': '+00:00'},
#   'description': 'Interested in consulting or business? Come practice cases '
#                  'with me--either in line with recruiting season or just for '
#                  'fun! ☺️',
#   'id': '-KvCfzN_jJXEdzZraMEP',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361705.509,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-82.9065344, 40.0424984],
#                'type': 'Point'},
#   'owner_id': '8nhkCkLxlmSNAuNgVW6y767p8uH3',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price_type': 'free',
#   'status': 'legacy',
#   'title': 'Consulting Cases',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Columbus',
#                              'country': 'US',
#                              'county': 'Franklin County',
#                              'number': '7',
#                              'state': 'OH',
#                              'street': 'Easton Oval',
#                              'zip_code': '43219'},
#               'formatted': '7 Easton Oval, Columbus, OH 43219, USA'},
#   'archived_status': 'live',
#   'category': 'Instructor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1506675310,
#                  'timezone': '+00:00'},
#   'description': "Hello! I would love to learn SAS/SQL. Let me know if you're "
#                  'knowledgeable in the area--would love to work with you.',
#   'id': '-KvCh6X3AZfxqwmZHg9V',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361720.526,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-82.9065344, 40.0424984],
#                'type': 'Point'},
#   'owner_id': '8nhkCkLxlmSNAuNgVW6y767p8uH3',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'request',
#   'price_type': 'free',
#   'status': 'legacy',
#   'title': 'SAS / SQL Tutor',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '184',
#                              'premise': 'Prince Engineering Laboratory',
#                              'state': 'RI',
#                              'street': 'Hope St',
#                              'zip_code': '02912'},
#               'formatted': 'Prince Engineering Laboratory, 184 Hope St, '
#                            'Providence, RI 02912, USA'},
#   'archived_status': 'live',
#   'category': 'Other',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1505483661,
#                  'timezone': '+00:00'},
#   'description': "From shooting, to editing, to audio mixing I'm able to help "
#                  'you bring whatever visual project you have in mind into '
#                  'reality.',
#   'id': '-Ku5fKhQcn_940qacVkr',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361720.128,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.398302, 41.8268574],
#                'type': 'Point'},
#   'owner_id': 'uGQ1ywtBJlbWpnMs7nibLtbV6v23',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'request',
#   'price': 25,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Video Production ',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '101',
#                              'state': 'RI',
#                              'street': 'Waterman St',
#                              'zip_code': '02912'},
#               'formatted': '101 Waterman St, Providence, RI 02912, USA'},
#   'archived_status': 'live',
#   'category': 'Other',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1507147280,
#                  'timezone': '+00:00'},
#   'description': 'You need to learn guitar to woo your lover. Let me help you '
#                  'out.',
#   'id': '-KvdpXj9N_Z96S4sR-fy',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361706.081,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.4005559, 41.8272892],
#                'type': 'Point'},
#   'owner_id': 'annW328DD1cDGQmYblc8CFrdxfI3',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 10,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Guitar Lessons',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '39',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '39 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Art & Design',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508974279,
#                  'timezone': '+00:00'},
#   'description': 'Willing to take on any photography projects!',
#   'id': '-KxLizDQ3n2WgiuFXop4',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361706.68,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3921977, 41.8255612],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 12,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Photography / Portraits',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '101',
#                              'state': 'RI',
#                              'street': 'Waterman St',
#                              'zip_code': '02912'},
#               'formatted': '101 Waterman St, Providence, RI 02912, USA'},
#   'archived_status': 'live',
#   'category': 'Other',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1507147212,
#                  'timezone': '+00:00'},
#   'description': 'Your tinder profile is not what it could be. Let me help you '
#                  'out 👍',
#   'id': '-KvdpH-Zu3_mCF8G103C',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361706.034,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.4005559, 41.8272892],
#                'type': 'Point'},
#   'owner_id': 'annW328DD1cDGQmYblc8CFrdxfI3',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 3,
#   'price_type': 'set_price',
#   'status': 'active',
#   'title': 'Help Your Tinder Profile',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '101',
#                              'state': 'RI',
#                              'street': 'Waterman St',
#                              'zip_code': '02912'},
#               'formatted': '101 Waterman St, Providence, RI 02912, USA'},
#   'archived_status': 'live',
#   'category': 'Art & Design',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1507147012,
#                  'timezone': '+00:00'},
#   'description': 'Do you want your bae to know how much you love them but you '
#                  "don't know how to tell them?? I'll write you a "
#                  '~personalized~ love song and record it and then you can '
#                  'memorize it, sing it, and pass it off as your own ❤️',
#   'id': '-KvdoW7J539gGqraXfEn',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361705.818,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.4005559, 41.8272892],
#                'type': 'Point'},
#   'owner_id': 'annW328DD1cDGQmYblc8CFrdxfI3',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 30,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Custom Love Song 😍😍😍',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '18',
#                              'state': 'RI',
#                              'street': 'Cole Ave',
#                              'zip_code': '02906'},
#               'formatted': '18 Cole Ave, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Muscle',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1506718624,
#                  'timezone': '+00:00'},
#   'description': 'Looking for a workout partner who would join me at the gym '
#                  "~3x a week. I'll help motivate you and I'll be your spotter "
#                  "when you need it if you can do the same in return. Let's get "
#                  'swole!',
#   'id': '-KuKqbXbPyATe2U6Y6i8',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361720.466,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.387382, 41.834088],
#                'type': 'Point'},
#   'owner_id': 'RHCWoC5WnSTXi0JWJadv18ejPwy1',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'request',
#   'price': 0,
#   'price_type': 'free',
#   'status': 'legacy',
#   'title': 'Gym Buddy',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Columbus',
#                              'country': 'US',
#                              'county': 'Franklin County',
#                              'number': '7',
#                              'state': 'OH',
#                              'street': 'Easton Oval',
#                              'zip_code': '43219'},
#               'formatted': '7 Easton Oval, Columbus, OH 43219, USA'},
#   'archived_status': 'live',
#   'category': 'Labor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1506675404,
#                  'timezone': '+00:00'},
#   'description': 'Feeling down or unmotivated? Hit me up!! I will give you a '
#                  'personalized pep talk and cheer you on!!!!',
#   'id': '-KvChTWqNEG8YMcn_06b',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361705.621,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-82.9065344, 40.0424984],
#                'type': 'Point'},
#   'owner_id': '8nhkCkLxlmSNAuNgVW6y767p8uH3',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price_type': 'free',
#   'status': 'legacy',
#   'title': 'Personal Cheerleader',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '39',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '39 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Electronics',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508975373,
#                  'timezone': '+00:00'},
#   'description': 'Fan works perfectly fine. ',
#   'id': '-KxLn9JtzZo1zhg5tRbb',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361698.252,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3921977, 41.8255612],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': ['1530682573'],
#   'post_type': 'offering',
#   'price': 12,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Fan',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '184',
#                              'premise': 'Prince Engineering Laboratory',
#                              'state': 'RI',
#                              'street': 'Hope St',
#                              'zip_code': '02912'},
#               'formatted': 'Prince Engineering Laboratory, 184 Hope St, '
#                            'Providence, RI 02912, USA'},
#   'archived_status': 'live',
#   'category': 'Other',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1505749403,
#                  'timezone': '+00:00'},
#   'description': 'Helps you figure out CS problems. Great listener. ',
#   'id': '-KuLW32ih-vA7iHEVO37',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361696.81,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.398302, 41.8268574],
#                'type': 'Point'},
#   'owner_id': 'zrbigYwCTzggBURdm89fNLstvBy2',
#   'payment_type': 'fixed',
#   'photos': ['1527456603'],
#   'post_type': 'offering',
#   'price': 100,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Lil Ducky',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'SF',
#                              'country': 'US',
#                              'county': 'San Francisco County',
#                              'number': '1',
#                              'state': 'CA',
#                              'street': 'Stockton St',
#                              'zip_code': '94108'},
#               'formatted': '1 Stockton St, San Francisco, CA 94108, USA'},
#   'archived_status': 'live',
#   'category': 'Instructor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508268614,
#                  'timezone': '+00:00'},
#   'description': 'I’ll teach you how to ride.  On college hill.',
#   'id': '-Kwgf4ytNsOJeuP4i2d0',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361706.289,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-122.4065081, 37.78586],
#                'type': 'Point'},
#   'owner_id': 'zrbigYwCTzggBURdm89fNLstvBy2',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 25,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Snowboarding Lessons',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '39',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '39 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Furniture',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508974800,
#                  'timezone': '+00:00'},
#   'description': 'Never used. Works perfectly. Approximately 20$ per drawer at '
#                  'bed bath and beyond, but willing to sell for 15 each. \n'
#                  '\n'
#                  '3 drawers',
#   'id': '-KxLkySUYsMAw1JmmLRI',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361697.697,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3921977, 41.8255612],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': ['1530682000'],
#   'post_type': 'offering',
#   'price': 15,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Bed Bath & Beyond Drawers',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'La Mirada',
#                              'country': 'US',
#                              'county': 'Los Angeles County',
#                              'number': '11926',
#                              'state': 'CA',
#                              'street': 'La Mirada Blvd',
#                              'zip_code': '90638'},
#               'formatted': '11926 La Mirada Blvd, La Mirada, CA 90638, USA'},
#   'archived_status': 'live',
#   'category': 'Instructor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508507667,
#                  'timezone': '+00:00'},
#   'description': 'I can teach u math!',
#   'id': '-KwvZC4JwzMh9CGpz0gF',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361706.515,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-118.0108321, 33.9218066],
#                'type': 'Point'},
#   'owner_id': 'RHCWoC5WnSTXi0JWJadv18ejPwy1',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 20,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Math Tutor',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '39',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '39 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Furniture',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508974656,
#                  'timezone': '+00:00'},
#   'description': '3 Head lamp. Bulbs included! Works perfectly',
#   'id': '-KxLkQPHY0fRmICue0fV',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361697.436,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3921977, 41.8255612],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': ['1530681856'],
#   'post_type': 'offering',
#   'price': 20,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': '3 Head Lamp',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '84',
#                              'state': 'RI',
#                              'street': 'Waterman St',
#                              'zip_code': '02906'},
#               'formatted': '84 Waterman St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Labor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1506209973,
#                  'timezone': '+00:00'},
#   'description': 'I build cutting-edge websites for startups, portfolios, and '
#                  'more.  Check out some of my work on http://michaelsnower.com '
#                  '!',
#   'id': '-KulxErAm-nrGZ9auusc',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361705.048,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.4021786, 41.8273613],
#                'type': 'Point'},
#   'owner_id': 'C5sf1L6IN3eK5Ws1jAuiEQDH2aq2',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 20,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Web Development',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '33',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '33 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Electronics',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508975024,
#                  'timezone': '+00:00'},
#   'description': 'Rice cooker. Works fine. Just need to get it out of the '
#                  'house',
#   'id': '-KxLlpDGjswYCG4MEpur',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361697.874,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3923921, 41.8255908],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': ['1530682224'],
#   'post_type': 'offering',
#   'price': 10,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Rice Cooking Pot',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'premise': 'Barbour Hall',
#                              'state': 'RI',
#                              'zip_code': '02912'},
#               'formatted': 'Barbour Hall, Providence, RI 02912, USA'},
#   'archived_status': 'live',
#   'category': 'Instructor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1509542020,
#                  'timezone': '+00:00'},
#   'description': 'Five-time startup employee + founded 2 startups. I’ll teach '
#                  'you how I got my offers',
#   'id': '-KxsZhKkQoiCK7YvD5Xp',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361707.401,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.39806829999999, 41.8239499],
#                'type': 'Point'},
#   'owner_id': '4CdxBeD0XAPqQS9z4az5CZkmsCg1',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 15,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Get A Startup Job',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '39',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '39 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Other',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508974501,
#                  'timezone': '+00:00'},
#   'description': '140$ tennis racket for sale! Head tennis racket. Head '
#                  'brand. ',
#   'id': '-KxLjpW58XHJQi1Vxu2g',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361697.226,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3921977, 41.8255612],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': ['1530681701'],
#   'post_type': 'offering',
#   'price': 30,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Tennis Racket',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '33',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '33 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Electronics',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508976752,
#                  'timezone': '+00:00'},
#   'description': 'Alarm clock. Works perfectly. Try not to snooze too much',
#   'id': '-KxLsQ6CAwmkqk9iAqUd',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361698.432,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3923921, 41.8255908],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': ['1530683952'],
#   'post_type': 'offering',
#   'price': 6,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Alarm Clock / Clock',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '39',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '39 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Other',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508977069,
#                  'timezone': '+00:00'},
#   'description': 'Orgo kit',
#   'id': '-KxLtcRjWWfS0G6Hej4j',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361699.261,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3921977, 41.8255612],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': ['1530684269'],
#   'post_type': 'offering',
#   'price': 12,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Orgo Kit',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Columbus',
#                              'country': 'US',
#                              'county': 'Franklin County',
#                              'number': '3866',
#                              'state': 'OH',
#                              'street': 'Townsfair Way',
#                              'zip_code': '43219'},
#               'formatted': '3866 Townsfair Way, Columbus, OH 43219, USA'},
#   'archived_status': 'live',
#   'category': 'Instructor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508626896,
#                  'timezone': '+00:00'},
#   'description': 'Teach me CS!! Would love to learn Python, web development, '
#                  'OOP, other relevant things 👩🏻\u200d💻',
#   'id': '-Kx10outQU8H8e3pHmvI',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361720.7,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-82.9185486, 40.0493519],
#                'type': 'Point'},
#   'owner_id': '8nhkCkLxlmSNAuNgVW6y767p8uH3',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'request',
#   'price_type': 'free',
#   'status': 'legacy',
#   'title': 'CS Tutor',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '39',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '39 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Electronics',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508976900,
#                  'timezone': '+00:00'},
#   'description': 'Ethernet cord. Rarely used',
#   'id': '-KxLsz52Nff6z3c57qVg',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361698.891,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3921977, 41.8255612],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': ['1530684100'],
#   'post_type': 'offering',
#   'price': 6,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Ethernet Cable',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Columbus',
#                              'country': 'US',
#                              'county': 'Franklin County',
#                              'number': '7',
#                              'state': 'OH',
#                              'street': 'Easton Oval',
#                              'zip_code': '43219'},
#               'formatted': '7 Easton Oval, Columbus, OH 43219, USA'},
#   'archived_status': 'live',
#   'category': 'Labor',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1506675147,
#                  'timezone': '+00:00'},
#   'description': "I'll help you manage all your social media accounts and work "
#                  'with you to make a marketing plan, for both business or '
#                  'personal. Has experience with content marketing, blogging, '
#                  'and ecommerce',
#   'id': '-KvCgUp3tWppVslh7vhr',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361705.571,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-82.9065344, 40.0424984],
#                'type': 'Point'},
#   'owner_id': '8nhkCkLxlmSNAuNgVW6y767p8uH3',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 10,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Social Media Management',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '39',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '39 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Electronics',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508976808,
#                  'timezone': '+00:00'},
#   'description': 'Wired mouse',
#   'id': '-KxLscj5sTYxNhiU93iN',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361698.608,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3921977, 41.8255612],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': ['1530684008'],
#   'post_type': 'offering',
#   'price': 3,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Mouse',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'premise': 'Harkness',
#                              'state': 'RI',
#                              'zip_code': '02906'},
#               'formatted': 'Harkness, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Other',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1509803192,
#                  'timezone': '+00:00'},
#   'description': 'Event, product, or portrait photography.\n'
#                  "I have many years of experience and good equipment. I'm "
#                  'happy to send you examples of my work.\n'
#                  'Fee is negotiable for individuals and student groups with '
#                  'limited budgets.',
#   'id': '-Ky73zGYwuKmlwpeaQM7',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361707.919,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.4006754, 41.824015],
#                'type': 'Point'},
#   'owner_id': 'iLvwMkxuobf28luG2RI4yq0clPI3',
#   'payment_type': 'fixed',
#   'photos': ['1531510392372', '2531510392372', '3531510392372'],
#   'post_type': 'offering',
#   'price': 20,
#   'price_type': 'flexible',
#   'status': 'legacy',
#   'title': 'Photography',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '39',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
#               'formatted': '39 E George St, Providence, RI 02906, USA'},
#   'archived_status': 'live',
#   'category': 'Furniture',
#   'content_type': 'good',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1508976970,
#                  'timezone': '+00:00'},
#   'description': 'Bed bath & beyond bed raises. Works perfectly',
#   'id': '-KxLtFGvQjDH1uegGAI2',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1536361699.065,
#                     'timezone': '+00:00'},
#   'location': {'$reql_type$': 'GEOMETRY',
#                'coordinates': [-71.3921977, 41.8255612],
#                'type': 'Point'},
#   'owner_id': 'OrgWwVMiKKcs8ib1rKT9jWrM7uw2',
#   'payment_type': 'fixed',
#   'photos': ['1530684170'],
#   'post_type': 'offering',
#   'price': 12,
#   'price_type': 'set_price',
#   'status': 'legacy',
#   'title': 'Bed Raises',
#   'visibility': 'public'},
#  {'address': {'components': {'city': 'Providence',
#                              'country': 'US',
#                              'county': 'Providence County',
#                              'number': '33',
#                              'state': 'RI',
#                              'street': 'E George St',
#                              'zip_code': '02906'},
# ...
#   'description': 'I can help with history essays, or math and Econ problem '
#                  'sets. ',
#   'id': 'f24bfb36-0eb5-4b80-86b9-f567813b81b4',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1541909946.249,
#                     'timezone': '+00:00'},
#   'owner_id': '831a9726-6272-418a-8416-00b1a5b0bd25',
#   'payment_type': 'hourly',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 20,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Homework help',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'other_service',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1541740777.251,
#                  'timezone': '+00:00'},
#   'description': 'We can talk about our lives experiences and figure out how '
#                  'to better ourselves. ',
#   'id': 'ebd75bba-7a56-424f-8594-ed96b1a64ae6',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1541740777.251,
#                     'timezone': '+00:00'},
#   'owner_id': '7977fea8-cb0e-4ee2-9b89-1a252ba80226',
#   'payment_type': 'hourly',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 7,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Personal Advice ',
#   'visibility': 'all_colleges'},
#  {'archivedStatus': 'live',
#   'archived_status': 'live',
#   'category': 'other_service',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1541595009.902,
#                  'timezone': '+00:00'},
#   'description': 'I watch a lot of anime and have good recommendations. Down '
#                  'to take recommendations too.',
#   'id': 'e1832dff-4ede-46d8-8daa-5490475d11eb',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1541595009.902,
#                     'timezone': '+00:00'},
#   'owner_id': '2ff0f1b5-b7ba-49ae-bb75-98f17fd57cda',
#   'payment_type': 'hourly',
#   'photos': [],
#   'post_type': 'offering',
#   'price': None,
#   'price_type': 'free',
#   'status': 'active',
#   'title': 'Anime Recommendations',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'photography',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1542476454.532,
#                  'timezone': '+00:00'},
#   'description': 'I need some professional photos taken please help me out ',
#   'id': 'fd669e31-c16b-4cb6-8852-dd02cf400b48',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1542476454.532,
#                     'timezone': '+00:00'},
#   'owner_id': 'OnzEfo1KIOXgNxr0UGyTqyKZEt73',
#   'payment_type': 'hourly',
#   'payment_type_new': 'hourly',
#   'photos': [],
#   'post_type': 'request',
#   'price': 0,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Photoshoot',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'instruction',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1542657339.819,
#                  'timezone': '+00:00'},
#   'description': 'I wanna lean!',
#   'id': 'ed02a042-3733-4654-b74c-87fc2903d8d9',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1542657339.819,
#                     'timezone': '+00:00'},
#   'owner_id': 'b2ccf00c-5c58-4ef1-9858-1b61dac7b920',
#   'payment_type': 'hourly',
#   'payment_type_new': 'hourly',
#   'photos': [],
#   'post_type': 'request',
#   'price': 25,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Piano Lessons',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'instruction',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1542590784.372,
#                  'timezone': '+00:00'},
#   'description': 'I can proofread and edit essays/papers for you ',
#   'id': 'e1bc0e59-007e-4e8c-abb7-057a908d9cd6',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1542590784.372,
#                     'timezone': '+00:00'},
#   'owner_id': '22c9af0b-6e29-4e76-a6df-9181ff828e3b',
#   'payment_type': 'hourly',
#   'payment_type_new': 'hourly',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 25,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Proofreading/Editing',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'design',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1541391789.443,
#                  'timezone': '+00:00'},
#   'description': 'I’m a Senior Violist at Texas Tech, need to have some cover '
#                  'art for my recital poster. \n'
#                  '\n'
#                  '\n'
#                  '\n'
#                  '\n'
#                  '\n'
#                  'Violist \n',
#   'id': 'fe2ece63-42e7-4d37-95e6-bac010bd0531',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1541391789.443,
#                     'timezone': '+00:00'},
#   'owner_id': '99c56763-0b71-474b-849a-d71f5d35c56d',
#   'payment_type': 'hourly',
#   'photos': ['01541391789187'],
#   'post_type': 'request',
#   'price': 25,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Recital Poster',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'design',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1542319148.103,
#                  'timezone': '+00:00'},
#   'description': 'I am looking for a graphic designer to create a company '
#                  'logo. ',
#   'id': 'f0d72b22-7ad5-43fb-8542-a0efe1065fa7',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1542319148.103,
#                     'timezone': '+00:00'},
#   'owner_id': 'b6d2d8d9-fc94-4964-8bed-de2c6d999dd2',
#   'payment_type': 'hourly',
#   'payment_type_new': 'hourly',
#   'photos': [],
#   'post_type': 'request',
#   'price': 0,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Graphic Designer ',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'other_service',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1542668080.295,
#                  'timezone': '+00:00'},
#   'description': 'Ps4 controller for sale',
#   'id': 'e8d7c672-9150-4285-a07a-5352fd7f8c38',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1542668080.295,
#                     'timezone': '+00:00'},
#   'owner_id': '9b542077-9695-4808-afed-eb32ad6be83d',
#   'payment_type': 'hourly',
#   'payment_type_new': 'hourly',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 20,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Ps4 Controller',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'instruction',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1540496653.189,
#                  'timezone': '+00:00'},
#   'description': 'Camp Kingswood is looking to hire camp counselors for '
#                  'Photography, Videography, and Animation. Messsage for more '
#                  'info. ',
#   'id': 'f18f6b50-f1f2-4fb7-a6c1-a9eac76010c6',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1540496653.189,
#                     'timezone': '+00:00'},
#   'owner_id': 'b6328ec1-a546-4e66-a1b4-33e139cbd80e',
#   'payment_type': 'hourly',
#   'photos': [],
#   'post_type': 'request',
#   'price': None,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Camp counselor [Summer]',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'other_service',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1542056303.277,
#                  'timezone': '+00:00'},
#   'description': 'Sell me your printer\nPreferably laserjet\nSend me a offer',
#   'id': 'ec0de020-a72d-40cd-96c8-76d6efa18cc9',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1542056303.277,
#                     'timezone': '+00:00'},
#   'owner_id': '45b794db-0de3-4089-849f-53b2bb01156b',
#   'payment_type': 'hourly',
#   'photos': [],
#   'post_type': 'request',
#   'price': None,
#   'price_type': 'free',
#   'status': 'active',
#   'title': 'Looking to buy printer',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'instruction',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1542647863.988,
#                  'timezone': '+00:00'},
#   'description': 'Personal tutoring sessions for Econ courses',
#   'id': 'f1fb77e6-3c74-43b7-aaac-e9d01198c17b',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1542647863.988,
#                     'timezone': '+00:00'},
#   'owner_id': 'e0711daa-d8c5-405a-9f92-a0217d2a4c9a',
#   'payment_type': 'hourly',
#   'payment_type_new': 'hourly',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 25,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Econ Tutoring',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'design',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1540475109.003,
#                  'timezone': '+00:00'},
#   'description': 'Looking to build a website where a user can create an '
#                  'account, and upload pictures + descriptions.  An admin could '
#                  'then pull the pictures, alter them, and reupload them to the '
#                  'user account.  Hoping to continue the engagement after this '
#                  'project. ',
#   'id': 'ec11785e-cade-4ca6-9a91-963b630a7412',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1540475109.003,
#                     'timezone': '+00:00'},
#   'owner_id': '32af9241-04d8-428e-b5da-1b8a2131209e',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'request',
#   'price': 100,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Web Developer',
#   'visibility': 'all_colleges'},
#  {'archived_status': 'live',
#   'category': 'other_service',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1541568033.416,
#                  'timezone': '+00:00'},
#   'description': "Feeling tired? Frustrated? Me too! Let's talk about it.\n"
#                  '\n'
#                  'Disclaimer: I am not a licensed physician',
#   'id': 'f21df798-74ba-4e05-87be-933499506196',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1541568033.416,
#                     'timezone': '+00:00'},
#   'owner_id': '26987368-2192-469b-bdea-4ea3266c49b7',
#   'payment_type': 'hourly',
#   'photos': [],
#   'post_type': 'offering',
#   'price': None,
#   'price_type': 'free',
#   'status': 'active',
#   'title': 'Someone to vent too',
#   'visibility': 'all_colleges'},
#  {'archived_status': 'live',
#   'category': 'design',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1541286047.22,
#                  'timezone': '+00:00'},
#   'description': 'Make me dope logo',
#   'id': 'ed5bab0b-bf6f-453b-b456-2c2ad45e153d',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1541286047.22,
#                     'timezone': '+00:00'},
#   'owner_id': 'a1bb092b-7baa-40b8-94b2-6e69a288646f',
#   'payment_type': 'hourly',
#   'photos': [],
#   'post_type': 'request',
#   'price': 20,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Logo design',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'instruction',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1541555979.855,
#                  'timezone': '+00:00'},
#   'description': 'All styles!\n',
#   'id': 'f41d237a-d607-4c71-bf3d-33a422306423',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1541555979.856,
#                     'timezone': '+00:00'},
#   'owner_id': '2447cfe3-fb10-474b-921d-a6acf2bab33f',
#   'payment_type': 'hourly',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 15,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Dance Lessons',
#   'visibility': 'all_colleges'},
#  {'archived_status': 'live',
#   'category': 'other_service',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1538583179.352,
#                  'timezone': '+00:00'},
#   'description': "I'm broke, and was just reaching out to see if anyone had "
#                  'anything they needed help with. Thanks! ',
#   'id': 'f5d85ccd-0bfa-498e-9300-e5d8d3c5fc3e',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1538583179.352,
#                     'timezone': '+00:00'},
#   'owner_id': 'bf10d420-cef9-43c8-bd48-2d93e93139ae',
#   'payment_type': 'hourly',
#   'photos': [],
#   'post_type': 'offering',
#   'price': None,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Work wanted',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'design',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1538947376.38,
#                  'timezone': '+00:00'},
#   'description': 'Please help me organize my iPhone home screen. It’s giving '
#                  'me anxiety. ',
#   'id': 'fb8e671b-678a-4981-9ee3-13598114a2dd',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1538947376.38,
#                     'timezone': '+00:00'},
#   'owner_id': '59d5709a-3d18-4223-8903-fee2c58c8750',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'request',
#   'price': 10,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Organize my iPhone',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'other_service',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1542657262.583,
#                  'timezone': '+00:00'},
#   'description': 'I will walk your dog whenever wherever',
#   'id': 'fa6712bf-2fd2-4888-92b0-22cc952205df',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1542657262.583,
#                     'timezone': '+00:00'},
#   'owner_id': '394dc04a-fb08-469f-bb74-e642fa1d6c58',
#   'payment_type': 'hourly',
#   'payment_type_new': 'hourly',
#   'photos': [],
#   'post_type': 'offering',
#   'price': 15,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Dogwalking',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'other_service',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1541649033.758,
#                  'timezone': '+00:00'},
#   'description': 'Looking for some people to do claymation with',
#   'id': 'fc5a938b-cd99-4588-a43b-839441c64b7d',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1541649033.758,
#                     'timezone': '+00:00'},
#   'owner_id': '011dae23-d559-47da-a6c8-b48e299525de',
#   'payment_type': 'fixed',
#   'photos': [],
#   'post_type': 'request',
#   'price': None,
#   'price_type': 'free',
#   'status': 'inactive',
#   'title': 'Claymation',
#   'visibility': 'public'},
#  {'archived_status': 'live',
#   'category': 'design',
#   'content_type': 'service',
#   'created_at': {'$reql_type$': 'TIME',
#                  'epoch_time': 1542663474.954,
#                  'timezone': '+00:00'},
#   'description': 'I have meme ideas but no photoshop, please help me reach my '
#                  'full meme lord potential and whip up the memes for me.',
#   'id': 'ffdf5a49-7fd8-4afe-961e-07b98240dbca',
#   'last_modified': {'$reql_type$': 'TIME',
#                     'epoch_time': 1542663474.954,
#                     'timezone': '+00:00'},
#   'owner_id': '799e4d72-853c-4506-93b0-4ac017a4a08e',
#   'payment_type': 'hourly',
#   'payment_type_new': 'hourly',
#   'photos': [],
#   'post_type': 'request',
#   'price': 0,
#   'price_type': 'flexible',
#   'status': 'active',
#   'title': 'Wholesome memes',
#   'visibility': 'public'}]

# %%
with open('allPostData.json') as fresh_data:
    user_post = json.load(fresh_data)

#pprint(user_post)
df = pd.DataFrame.from_dict(json_normalize(user_post), orient='columns')
df
# Out:
#     address.components.city address.components.country  \
# 0                Providence                         US
# 1                Providence                         US
# 2                Providence                         US
# 3                Providence                         US
# 4                Providence                         US
# 5                Providence                         US
# 6                  Columbus                         US
# 7                Providence                         US
# 8                Providence                         US
# 9                  Columbus                         US
# 10                 Columbus                         US
# 11               Providence                         US
# 12               Providence                         US
# 13               Providence                         US
# 14               Providence                         US
# 15               Providence                         US
# 16               Providence                         US
# 17                 Columbus                         US
# 18               Providence                         US
# 19               Providence                         US
# 20                       SF                         US
# 21               Providence                         US
# 22                La Mirada                         US
# 23               Providence                         US
# 24               Providence                         US
# 25               Providence                         US
# 26               Providence                         US
# 27               Providence                         US
# 28               Providence                         US
# 29               Providence                         US
# ..                      ...                        ...
# 781                     NaN                        NaN
# 782                     NaN                        NaN
# 783                     NaN                        NaN
# 784                     NaN                        NaN
# 785                     NaN                        NaN
# 786                     NaN                        NaN
# 787                     NaN                        NaN
# 788                     NaN                        NaN
# 789                     NaN                        NaN
# 790                     NaN                        NaN
# 791                     NaN                        NaN
# 792                     NaN                        NaN
# 793                     NaN                        NaN
# 794                     NaN                        NaN
# 795                     NaN                        NaN
# 796                     NaN                        NaN
# 797                     NaN                        NaN
# 798                     NaN                        NaN
# 799                     NaN                        NaN
# 800                     NaN                        NaN
# 801                     NaN                        NaN
# 802                     NaN                        NaN
# 803                     NaN                        NaN
# 804                     NaN                        NaN
# 805                     NaN                        NaN
# 806                     NaN                        NaN
# 807                     NaN                        NaN
# 808                     NaN                        NaN
# 809                     NaN                        NaN
# 810                     NaN                        NaN
#
#     address.components.county address.components.number  \
# 0           Providence County                       158
# 1           Providence County                       157
# 2           Providence County                       233
# 3           Providence County                       152
# 4           Providence County                       184
# 5           Providence County                       157
# 6             Franklin County                         7
# 7           Providence County                       184
# 8           Providence County                         1
# 9             Franklin County                         7
# 10            Franklin County                         7
# 11          Providence County                       184
# 12          Providence County                       101
# 13          Providence County                        39
# 14          Providence County                       101
# 15          Providence County                       101
# 16          Providence County                        18
# 17            Franklin County                         7
# 18          Providence County                        39
# 19          Providence County                       184
# 20       San Francisco County                         1
# 21          Providence County                        39
# 22         Los Angeles County                     11926
# 23          Providence County                        39
# 24          Providence County                        84
# 25          Providence County                        33
# 26          Providence County                       NaN
# 27          Providence County                        39
# 28          Providence County                        33
# 29          Providence County                        39
# ..                        ...                       ...
# 781                       NaN                       NaN
# 782                       NaN                       NaN
# 783                       NaN                       NaN
# 784                       NaN                       NaN
# 785                       NaN                       NaN
# 786                       NaN                       NaN
# 787                       NaN                       NaN
# 788                       NaN                       NaN
# 789                       NaN                       NaN
# 790                       NaN                       NaN
# 791                       NaN                       NaN
# 792                       NaN                       NaN
# 793                       NaN                       NaN
# 794                       NaN                       NaN
# 795                       NaN                       NaN
# 796                       NaN                       NaN
# 797                       NaN                       NaN
# 798                       NaN                       NaN
# 799                       NaN                       NaN
# 800                       NaN                       NaN
# 801                       NaN                       NaN
# 802                       NaN                       NaN
# 803                       NaN                       NaN
# 804                       NaN                       NaN
# 805                       NaN                       NaN
# 806                       NaN                       NaN
# 807                       NaN                       NaN
# 808                       NaN                       NaN
# 809                       NaN                       NaN
# 810                       NaN                       NaN
#
#         address.components.premise address.components.state  \
# 0                              NaN                       RI
# 1                              NaN                       RI
# 2                              NaN                       RI
# 3                              NaN                       RI
# 4    Prince Engineering Laboratory                       RI
# 5                              NaN                       RI
# 6                              NaN                       OH
# 7    Prince Engineering Laboratory                       RI
# 8                              NaN                       RI
# 9                              NaN                       OH
# 10                             NaN                       OH
# 11   Prince Engineering Laboratory                       RI
# 12                             NaN                       RI
# 13                             NaN                       RI
# 14                             NaN                       RI
# 15                             NaN                       RI
# 16                             NaN                       RI
# 17                             NaN                       OH
# 18                             NaN                       RI
# 19   Prince Engineering Laboratory                       RI
# 20                             NaN                       CA
# 21                             NaN                       RI
# 22                             NaN                       CA
# 23                             NaN                       RI
# 24                             NaN                       RI
# 25                             NaN                       RI
# 26                    Barbour Hall                       RI
# 27                             NaN                       RI
# 28                             NaN                       RI
# 29                             NaN                       RI
# ..                             ...                      ...
# 781                            NaN                      NaN
# 782                            NaN                      NaN
# 783                            NaN                      NaN
# 784                            NaN                      NaN
# 785                            NaN                      NaN
# 786                            NaN                      NaN
# 787                            NaN                      NaN
# 788                            NaN                      NaN
# 789                            NaN                      NaN
# 790                            NaN                      NaN
# 791                            NaN                      NaN
# 792                            NaN                      NaN
# 793                            NaN                      NaN
# 794                            NaN                      NaN
# 795                            NaN                      NaN
# 796                            NaN                      NaN
# 797                            NaN                      NaN
# 798                            NaN                      NaN
# 799                            NaN                      NaN
# 800                            NaN                      NaN
# 801                            NaN                      NaN
# 802                            NaN                      NaN
# 803                            NaN                      NaN
# 804                            NaN                      NaN
# 805                            NaN                      NaN
# 806                            NaN                      NaN
# 807                            NaN                      NaN
# 808                            NaN                      NaN
# 809                            NaN                      NaN
# 810                            NaN                      NaN
#
#     address.components.street address.components.zip_code  \
# 0              University Ave                       02906
# 1              University Ave                       02906
# 2                     Hope St                       02906
# 3              University Ave                       02906
# 4                     Hope St                       02912
# 5              University Ave                       02906
# 6                 Easton Oval                       43219
# 7                     Hope St                       02912
# 8                 Prospect St                       02912
# 9                 Easton Oval                       43219
# 10                Easton Oval                       43219
# 11                    Hope St                       02912
# 12                Waterman St                       02912
# 13                E George St                       02906
# 14                Waterman St                       02912
# 15                Waterman St                       02912
# 16                   Cole Ave                       02906
# 17                Easton Oval                       43219
# 18                E George St                       02906
# 19                    Hope St                       02912
# 20                Stockton St                       94108
# 21                E George St                       02906
# 22             La Mirada Blvd                       90638
# 23                E George St                       02906
# 24                Waterman St                       02906
# 25                E George St                       02906
# 26                        NaN                       02912
# 27                E George St                       02906
# 28                E George St                       02906
# 29                E George St                       02906
# ..                        ...                         ...
# 781                       NaN                         NaN
# 782                       NaN                         NaN
# 783                       NaN                         NaN
# 784                       NaN                         NaN
# 785                       NaN                         NaN
# 786                       NaN                         NaN
# 787                       NaN                         NaN
# 788                       NaN                         NaN
# 789                       NaN                         NaN
# 790                       NaN                         NaN
# 791                       NaN                         NaN
# 792                       NaN                         NaN
# 793                       NaN                         NaN
# 794                       NaN                         NaN
# 795                       NaN                         NaN
# 796                       NaN                         NaN
# 797                       NaN                         NaN
# 798                       NaN                         NaN
# 799                       NaN                         NaN
# 800                       NaN                         NaN
# 801                       NaN                         NaN
# 802                       NaN                         NaN
# 803                       NaN                         NaN
# 804                       NaN                         NaN
# 805                       NaN                         NaN
# 806                       NaN                         NaN
# 807                       NaN                         NaN
# 808                       NaN                         NaN
# 809                       NaN                         NaN
# 810                       NaN                         NaN
#
#                                      address.formatted archivedStatus  \
# 0        158 University Ave, Providence, RI 02906, USA            NaN
# 1        157 University Ave, Providence, RI 02906, USA            NaN
# 2               233 Hope St, Providence, RI 02906, USA            NaN
# 3        152 University Ave, Providence, RI 02906, USA            NaN
# 4    Prince Engineering Laboratory, 184 Hope St, Pr...            NaN
# 5        157 University Ave, Providence, RI 02906, USA            NaN
# 6               7 Easton Oval, Columbus, OH 43219, USA            NaN
# 7    Prince Engineering Laboratory, 184 Hope St, Pr...            NaN
# 8             1 Prospect St, Providence, RI 02912, USA            NaN
# 9               7 Easton Oval, Columbus, OH 43219, USA            NaN
# 10              7 Easton Oval, Columbus, OH 43219, USA            NaN
# 11   Prince Engineering Laboratory, 184 Hope St, Pr...            NaN
# 12          101 Waterman St, Providence, RI 02912, USA            NaN
# 13           39 E George St, Providence, RI 02906, USA            NaN
# 14          101 Waterman St, Providence, RI 02912, USA            NaN
# 15          101 Waterman St, Providence, RI 02912, USA            NaN
# 16              18 Cole Ave, Providence, RI 02906, USA            NaN
# 17              7 Easton Oval, Columbus, OH 43219, USA            NaN
# 18           39 E George St, Providence, RI 02906, USA            NaN
# 19   Prince Engineering Laboratory, 184 Hope St, Pr...            NaN
# 20         1 Stockton St, San Francisco, CA 94108, USA            NaN
# 21           39 E George St, Providence, RI 02906, USA            NaN
# 22      11926 La Mirada Blvd, La Mirada, CA 90638, USA            NaN
# 23           39 E George St, Providence, RI 02906, USA            NaN
# 24           84 Waterman St, Providence, RI 02906, USA            NaN
# 25           33 E George St, Providence, RI 02906, USA            NaN
# 26             Barbour Hall, Providence, RI 02912, USA            NaN
# 27           39 E George St, Providence, RI 02906, USA            NaN
# 28           33 E George St, Providence, RI 02906, USA            NaN
# 29           39 E George St, Providence, RI 02906, USA            NaN
# ..                                                 ...            ...
# 781                                                NaN            NaN
# 782                                                NaN            NaN
# 783                                                NaN            NaN
# 784                                                NaN            NaN
# 785                                                NaN            NaN
# 786                                                NaN            NaN
# 787                                                NaN            NaN
# 788                                                NaN            NaN
# 789                                                NaN            NaN
# 790                                                NaN            NaN
# 791                                                NaN            NaN
# 792                                                NaN           live
# 793                                                NaN            NaN
# 794                                                NaN            NaN
# 795                                                NaN            NaN
# 796                                                NaN            NaN
# 797                                                NaN            NaN
# 798                                                NaN            NaN
# 799                                                NaN            NaN
# 800                                                NaN            NaN
# 801                                                NaN            NaN
# 802                                                NaN            NaN
# 803                                                NaN            NaN
# 804                                                NaN            NaN
# 805                                                NaN            NaN
# 806                                                NaN            NaN
# 807                                                NaN            NaN
# 808                                                NaN            NaN
# 809                                                NaN            NaN
# 810                                                NaN            NaN
#
#          ...                                   owner_id payment_type  \
# 0        ...               RHCWoC5WnSTXi0JWJadv18ejPwy1        fixed
# 1        ...               zrbigYwCTzggBURdm89fNLstvBy2        fixed
# 2        ...               zrbigYwCTzggBURdm89fNLstvBy2        fixed
# 3        ...               zrbigYwCTzggBURdm89fNLstvBy2        fixed
# 4        ...               2cAi0NSxlFVDlvRuHWxstNAMX5B2        fixed
# 5        ...               zrbigYwCTzggBURdm89fNLstvBy2        fixed
# 6        ...               8nhkCkLxlmSNAuNgVW6y767p8uH3        fixed
# 7        ...               RHCWoC5WnSTXi0JWJadv18ejPwy1        fixed
# 8        ...               uGQ1ywtBJlbWpnMs7nibLtbV6v23        fixed
# 9        ...               8nhkCkLxlmSNAuNgVW6y767p8uH3        fixed
# 10       ...               8nhkCkLxlmSNAuNgVW6y767p8uH3        fixed
# 11       ...               uGQ1ywtBJlbWpnMs7nibLtbV6v23        fixed
# 12       ...               annW328DD1cDGQmYblc8CFrdxfI3        fixed
# 13       ...               OrgWwVMiKKcs8ib1rKT9jWrM7uw2        fixed
# 14       ...               annW328DD1cDGQmYblc8CFrdxfI3        fixed
# 15       ...               annW328DD1cDGQmYblc8CFrdxfI3        fixed
# 16       ...               RHCWoC5WnSTXi0JWJadv18ejPwy1        fixed
# 17       ...               8nhkCkLxlmSNAuNgVW6y767p8uH3        fixed
# 18       ...               OrgWwVMiKKcs8ib1rKT9jWrM7uw2        fixed
# 19       ...               zrbigYwCTzggBURdm89fNLstvBy2        fixed
# 20       ...               zrbigYwCTzggBURdm89fNLstvBy2        fixed
# 21       ...               OrgWwVMiKKcs8ib1rKT9jWrM7uw2        fixed
# 22       ...               RHCWoC5WnSTXi0JWJadv18ejPwy1        fixed
# 23       ...               OrgWwVMiKKcs8ib1rKT9jWrM7uw2        fixed
# 24       ...               C5sf1L6IN3eK5Ws1jAuiEQDH2aq2        fixed
# 25       ...               OrgWwVMiKKcs8ib1rKT9jWrM7uw2        fixed
# 26       ...               4CdxBeD0XAPqQS9z4az5CZkmsCg1        fixed
# 27       ...               OrgWwVMiKKcs8ib1rKT9jWrM7uw2        fixed
# 28       ...               OrgWwVMiKKcs8ib1rKT9jWrM7uw2        fixed
# 29       ...               OrgWwVMiKKcs8ib1rKT9jWrM7uw2        fixed
# ..       ...                                        ...          ...
# 781      ...       c46b52a0-51ec-4a4e-8268-750ba75c590e       hourly
# 782      ...       1e7e342e-de50-44ed-95d3-d46d57123b00        fixed
# 783      ...       c489ebd1-f274-4c5a-bf75-3669b3ee41bb        fixed
# 784      ...       ad7650c4-c278-4600-b5e4-f245a0f90de7        fixed
# 785      ...       d6e6a000-3193-4231-a06e-4de35b8b0083       hourly
# 786      ...               e6HVhkaQenVp82UTLMmOs4T5HaX2        fixed
# 787      ...       543b6968-a6ae-4a02-b379-bae5de7946de        fixed
# 788      ...       a149048c-c418-43e8-98d2-0958e0a13398       hourly
# 789      ...       ed8f659f-2bec-4a9e-b34a-b924ef96c1bb       hourly
# 790      ...       831a9726-6272-418a-8416-00b1a5b0bd25       hourly
# 791      ...       7977fea8-cb0e-4ee2-9b89-1a252ba80226       hourly
# 792      ...       2ff0f1b5-b7ba-49ae-bb75-98f17fd57cda       hourly
# 793      ...               OnzEfo1KIOXgNxr0UGyTqyKZEt73       hourly
# 794      ...       b2ccf00c-5c58-4ef1-9858-1b61dac7b920       hourly
# 795      ...       22c9af0b-6e29-4e76-a6df-9181ff828e3b       hourly
# 796      ...       99c56763-0b71-474b-849a-d71f5d35c56d       hourly
# 797      ...       b6d2d8d9-fc94-4964-8bed-de2c6d999dd2       hourly
# 798      ...       9b542077-9695-4808-afed-eb32ad6be83d       hourly
# 799      ...       b6328ec1-a546-4e66-a1b4-33e139cbd80e       hourly
# 800      ...       45b794db-0de3-4089-849f-53b2bb01156b       hourly
# 801      ...       e0711daa-d8c5-405a-9f92-a0217d2a4c9a       hourly
# 802      ...       32af9241-04d8-428e-b5da-1b8a2131209e        fixed
# 803      ...       26987368-2192-469b-bdea-4ea3266c49b7       hourly
# 804      ...       a1bb092b-7baa-40b8-94b2-6e69a288646f       hourly
# 805      ...       2447cfe3-fb10-474b-921d-a6acf2bab33f       hourly
# 806      ...       bf10d420-cef9-43c8-bd48-2d93e93139ae       hourly
# 807      ...       59d5709a-3d18-4223-8903-fee2c58c8750        fixed
# 808      ...       394dc04a-fb08-469f-bb74-e642fa1d6c58       hourly
# 809      ...       011dae23-d559-47da-a6c8-b48e299525de        fixed
# 810      ...       799e4d72-853c-4506-93b0-4ac017a4a08e       hourly
#
#     payment_type_new                                            photos  \
# 0                NaN                                                []
# 1                NaN                                                []
# 2                NaN                                                []
# 3                NaN                                                []
# 4                NaN                                                []
# 5                NaN                                                []
# 6                NaN                                                []
# 7                NaN                                   [1532481234728]
# 8                NaN                                                []
# 9                NaN                                                []
# 10               NaN                                                []
# 11               NaN                                                []
# 12               NaN                                                []
# 13               NaN                                                []
# 14               NaN                                                []
# 15               NaN                                                []
# 16               NaN                                                []
# 17               NaN                                                []
# 18               NaN                                      [1530682573]
# 19               NaN                                      [1527456603]
# 20               NaN                                                []
# 21               NaN                                      [1530682000]
# 22               NaN                                                []
# 23               NaN                                      [1530681856]
# 24               NaN                                                []
# 25               NaN                                      [1530682224]
# 26               NaN                                                []
# 27               NaN                                      [1530681701]
# 28               NaN                                      [1530683952]
# 29               NaN                                      [1530684269]
# ..               ...                                               ...
# 781           hourly                                                []
# 782              NaN                                                []
# 783              NaN                                                []
# 784              NaN  [01538251112461, 11538251112461, 21538251112461]
# 785              NaN                                                []
# 786              NaN                                                []
# 787              NaN                                                []
# 788              NaN                                                []
# 789              NaN                                                []
# 790              NaN                                                []
# 791              NaN                                                []
# 792              NaN                                                []
# 793           hourly                                                []
# 794           hourly                                                []
# 795           hourly                                                []
# 796              NaN                                  [01541391789187]
# 797           hourly                                                []
# 798           hourly                                                []
# 799              NaN                                                []
# 800              NaN                                                []
# 801           hourly                                                []
# 802              NaN                                                []
# 803              NaN                                                []
# 804              NaN                                                []
# 805              NaN                                                []
# 806              NaN                                                []
# 807              NaN                                                []
# 808           hourly                                                []
# 809              NaN                                                []
# 810           hourly                                                []
#
#     post_type  price price_type    status  \
# 0     request     25   flexible    legacy
# 1    offering     15   flexible    legacy
# 2     request     15   flexible    legacy
# 3    offering     15   flexible    legacy
# 4    offering     15  set_price    legacy
# 5    offering    NaN       free    legacy
# 6    offering      2   flexible    legacy
# 7    offering      4  set_price    legacy
# 8    offering     20   flexible    legacy
# 9    offering    NaN       free    legacy
# 10    request    NaN       free    legacy
# 11    request     25   flexible    legacy
# 12   offering     10   flexible    active
# 13   offering     12   flexible    legacy
# 14   offering      3  set_price    active
# 15   offering     30   flexible    legacy
# 16    request      0       free    legacy
# 17   offering    NaN       free    legacy
# 18   offering     12  set_price    legacy
# 19   offering    100  set_price    legacy
# 20   offering     25  set_price    legacy
# 21   offering     15  set_price    legacy
# 22   offering     20   flexible    legacy
# 23   offering     20  set_price    legacy
# 24   offering     20   flexible    legacy
# 25   offering     10  set_price    legacy
# 26   offering     15  set_price    legacy
# 27   offering     30  set_price    legacy
# 28   offering      6  set_price    legacy
# 29   offering     12  set_price    legacy
# ..        ...    ...        ...       ...
# 781   request      0   flexible    frozen
# 782  offering     15   flexible    active
# 783  offering     20   flexible    active
# 784  offering    230   flexible  inactive
# 785   request     10   flexible  inactive
# 786  offering      2   flexible    active
# 787  offering     50   flexible    active
# 788  offering     16   flexible  inactive
# 789  offering     10   flexible  inactive
# 790  offering     20   flexible    active
# 791  offering      7   flexible    active
# 792  offering   None       free    active
# 793   request      0   flexible    active
# 794   request     25   flexible    active
# 795  offering     25   flexible    active
# 796   request     25   flexible    active
# 797   request      0   flexible    active
# 798  offering     20   flexible    active
# 799   request   None   flexible    active
# 800   request   None       free    active
# 801  offering     25   flexible    active
# 802   request    100   flexible    active
# 803  offering   None       free    active
# 804   request     20   flexible    active
# 805  offering     15   flexible    active
# 806  offering   None   flexible    active
# 807   request     10   flexible    active
# 808  offering     15   flexible    active
# 809   request   None       free  inactive
# 810   request      0   flexible    active
#
#                                      title    visibility
# 0                    Teach Me How To Cook!        public
# 1                    Long Boarding Lessons        public
# 2                         Personal Trainer        public
# 3                     Final Cut Pro Lesson        public
# 4                          Resume Building        public
# 5                    Motivational Pep Talk        public
# 6                   Resume + Cover Letter         public
# 7                        Paracord Bracelet        public
# 8                        Video Production         public
# 9                         Consulting Cases        public
# 10                         SAS / SQL Tutor        public
# 11                       Video Production         public
# 12                          Guitar Lessons        public
# 13                 Photography / Portraits        public
# 14                Help Your Tinder Profile        public
# 15                    Custom Love Song 😍😍😍        public
# 16                               Gym Buddy        public
# 17                    Personal Cheerleader        public
# 18                                     Fan        public
# 19                               Lil Ducky        public
# 20                    Snowboarding Lessons        public
# 21               Bed Bath & Beyond Drawers        public
# 22                              Math Tutor        public
# 23                             3 Head Lamp        public
# 24                         Web Development        public
# 25                        Rice Cooking Pot        public
# 26                       Get A Startup Job        public
# 27                           Tennis Racket        public
# 28                     Alarm Clock / Clock        public
# 29                                Orgo Kit        public
# ..                                     ...           ...
# 781                            Thick Booty        public
# 782                           Voice Acting        public
# 783                       Laundry service         public
# 784                         Galaxy s7 edge        public
# 785     Looking to take care of a bulldog!        public
# 786  /competitively priced/ meme photoshop        public
# 787                          Music Lessons        public
# 788                Personal pet for a day         public
# 789                        Seasonal Photos        public
# 790                          Homework help        public
# 791                       Personal Advice   all_colleges
# 792                  Anime Recommendations        public
# 793                             Photoshoot        public
# 794                          Piano Lessons        public
# 795                   Proofreading/Editing        public
# 796                         Recital Poster        public
# 797                      Graphic Designer         public
# 798                         Ps4 Controller        public
# 799                Camp counselor [Summer]        public
# 800                 Looking to buy printer        public
# 801                          Econ Tutoring        public
# 802                          Web Developer  all_colleges
# 803                    Someone to vent too  all_colleges
# 804                            Logo design        public
# 805                          Dance Lessons  all_colleges
# 806                            Work wanted        public
# 807                     Organize my iPhone        public
# 808                             Dogwalking        public
# 809                             Claymation        public
# 810                        Wholesome memes        public
#
# [811 rows x 103 columns]

# %%
#Preprocessing and reading the data
allposts = pd.read_csv("allPostData.csv", header=0)
allposts.head()
# Out:
#   archivedStatus address__components__city address__components__country  \
# 0            NaN                Providence                           US
# 1            NaN                Providence                           US
# 2            NaN                Providence                           US
# 3            NaN                Providence                           US
# 4            NaN                Providence                           US
#
#   address__components__county address__components__number  \
# 0           Providence County                         158
# 1           Providence County                         157
# 2           Providence County                         233
# 3           Providence County                         152
# 4           Providence County                         184
#
#     address__components__premise address__components__state  \
# 0                            NaN                         RI
# 1                            NaN                         RI
# 2                            NaN                         RI
# 3                            NaN                         RI
# 4  Prince Engineering Laboratory                         RI
#
#   address__components__street  address__components__zip_code  \
# 0              University Ave                         2906.0
# 1              University Ave                         2906.0
# 2                     Hope St                         2906.0
# 3              University Ave                         2906.0
# 4                     Hope St                         2912.0
#
#                                   address__formatted    ...     photos__001  \
# 0      158 University Ave, Providence, RI 02906, USA    ...             NaN
# 1      157 University Ave, Providence, RI 02906, USA    ...             NaN
# 2             233 Hope St, Providence, RI 02906, USA    ...             NaN
# 3      152 University Ave, Providence, RI 02906, USA    ...             NaN
# 4  Prince Engineering Laboratory, 184 Hope St, Pr...    ...             NaN
#
#   photos__002 photos__003 photos__004 post_type  price price_type  status  \
# 0         NaN         NaN         NaN   request   25.0   flexible  legacy
# 1         NaN         NaN         NaN  offering   15.0   flexible  legacy
# 2         NaN         NaN         NaN   request   15.0   flexible  legacy
# 3         NaN         NaN         NaN  offering   15.0   flexible  legacy
# 4         NaN         NaN         NaN  offering   15.0  set_price  legacy
#
#                    title visibility
# 0  Teach Me How To Cook!     public
# 1  Long Boarding Lessons     public
# 2       Personal Trainer     public
# 3   Final Cut Pro Lesson     public
# 4        Resume Building     public
#
# [5 rows x 105 columns]

# %% [markdown]
# #### (6) Similarity Queries
#
# Now that we've seen that this is not a 2-D problem, but indeed a multidimensional problem, we'll perform similarity queries. This means that, given the title vectors we have, one from our Pangea dictionary and the other for new data coming in (supposedly real-time in future state), we want to see how similar these titles are. The more similar the titles, the more likely they would be a good recommendation for our Pangean.
#
# To study title similarities, we'll be using the dot product of the vectors (or the cosine similarity). The higher the dot product, the more similar the titles will be. Titles that are exactly the same will have a dot product of 1.

# %%
titles_w_sim_rank = []

# %%
title_vectors['teach'][:30]
# Out:
# array([ 0.04235635, -0.01368302,  0.07774045,  0.02823756,  0.04200774,
#         0.04462232,  0.08750159, -0.04775983, -0.06170431, -0.06867655,
#         0.05961264,  0.04880567, -0.02143963,  0.07285989, -0.04427371,
#         0.07878629, -0.0613557 ,  0.09342799, -0.01655907, -0.06763071,
#         0.12550029,  0.06797932,  0.10388635,  0.07355712, -0.05403485,
#        -0.08122657, -0.00155786, -0.03067785, -0.03433827, -0.03276952],
#       dtype=float32)

# %%
title_vectors.keys()
# Out:
# dict_keys(['teach', 'long boarding lessons', 'personal trainer', 'final cut pro lesson', 'resume building', 'motivational pep talk', 'resume cover letter', 'bracelet', 'video production', 'consulting cases', 'sas sql tutor', 'guitar lessons', 'photography portraits', 'help tinder profile', 'custom love song', 'gym buddy', 'personal cheerleader', 'fan', 'lil ducky', 'snowboarding lessons', 'bed bath beyond drawers', 'math tutor', 'head lamp', 'web development', 'rice cooking pot', 'get startup job', 'tennis racket', 'alarm clock clock', 'orgo kit', 'cs tutor', 'ethernet cable', 'social media management', 'mouse', 'photography', 'bed raises', 'tv screen', 'homecooked dinner', 'ig social media marketing', 'developer', 'iron', 'soccer lessons', 'idea help', 'korean tutor', 'adobe photoshop help', 'desk lamps', 'ride boston', 'increase gym gains', 'adobe illustrator help', 'headshots', 'laundry', 'programming advise', 'original prints', 'massage', 'free', 'workout plan', 'design coolest debit card', 'feedback', 'accounting help', 'piano lessons', 'graphic designer', 'holiday cocktail', 'buy groceries', 'latex tutor', 'reviews', 'photos', 'wine recommendations', 'looking animator', 'venture help', 'promotional memes', 'watermark', 'filmmaking', 'bate lessons', 'beginner chess lessons', 'league legends mentor', 'grocery runs', 'portrait photography', 'custom artwork', 'pump u abt ur dog', 'haircut', 'steve madden heel booties', 'landscape photography', 'event photography', 'chef prepared meal prep', 'golf lessons', 'origami lessons', 'ride porsche cayenne', 'learn harmonize', 'free cookies', 'official munchies', 'scarves', 'campus ambassador', 'spanish tutor', 'eliminate russell carey replace robot', 'search engine', 'beats studio wireless', 'explore ri', 'tennis lessons', 'general stylist', 'social', 'research', '', 'cube', 'lots photo', 'tech interview prep', 'chromosomes', 'ice cream sandwiches', 'meal swipes', 'help moving bed', 'ladies burgundy moto jacket', 'really cool friend', 'wisdom', 'meal credit', 'learn', 'reminders', 'wordsmith', 'sas', 'weekly movie recommendations', 'singing lessons', 'drink wine', 'hang cool', 'raf simons', 'tax prep', 'looking social media coordinator', 'art commissions', 'cupcake delivery', 'quick sell air force', 'teach solve cube', 'led book light', 'fine arts printing', 'please buy ben ice cream', 'help frame two canvas', 'lessons', 'santa cruz bigfoot longboard', 'let videography something cool', 'driver', 'post consulting', 'smash tutor', 'cleaning', 'diamond snapback', 'free cupcake', 'free brownies', 'looking graphic design', 'test post', 'apt cleaner', 'eating coach', 'pretend dad hire', 'roll electronic drum kit', 'graduation', 'puma shoes jordan', 'dev', 'league lessons', 'software engineer needed small proj', 'dog walker', 'financial services', 'help sell', 'need print spring weekend', 'moving help', 'personal organizer', 'bartender', 'need help history', 'french tutoring', 'tutoring', 'parking spot', 'ice cream delivery', 'friends ohio', 'teach meme culture', 'looking players', 'metal shop cleaner', 'mini camera', 'photoshop', 'logo help', 'mario kart tutor', 'fantasy football consulting', 'smash partner', 'farm fresh meal', 'amazon echo', 'boba buddy', 'prototype needed', 'website build', 'need fabrics', 'pet photography', 'funding', 'league legends booster', 'help hanging lights common room', 'improv acting lessons', 'help learn dance', 'wedding', 'coding advice', 'crocheting lessons', 'chem tutor', 'melee tutoring', 'tutoring gov lessons', 'marketing lessons', 'live', 'indesign tutoring', 'linkedin advice', 'pretend boyfriend', 'tarot card readings', 'recycling tips', 'violin basics', 'software design internship', 'tips writing paper', 'video making lessons', 'jalapeno chips', 'chemistry tutor', 'social media content creator', 'play league legends', 'designing website', 'image vector conversion', 'recruiting help', 'make waffles', 'stuff', 'photographer', 'looking group', 'caricature ...

# %% [markdown]
# *Title_vectors* is actually a dictionary--which makes it a really special and useful datatype for our title vectors. Some useful links I found when using python dictionaries are the following:
# - https://stackoverflow.com/questions/6634708/typeerror-dict-object-is-not-callable
# - https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value
# - https://www.w3schools.com/python/python_dictionaries.asp
#
# We can then print out all the "keys" of the *title_vectors* dictionary to see the list of all of our titles.
#
# For a deeper look into dot product, we want to test out the semantics below:
#
# A couple resources that I found particularly helpful when learning about dot product are the following:
# - https://en.wikipedia.org/wiki/Dot_product
# - https://www.mathsisfun.com/algebra/vectors-dot-product.html
# - https://betterexplained.com/articles/vector-calculus-understanding-the-dot-product/
# - http://tutorial.math.lamar.edu/Classes/CalcII/DotProduct.aspx

# %%
#testing semantics
np.dot(title_vectors['teach'], title_vectors['chemistry tutor'])
# Out:
# 0.4491459

# %% [markdown]
# We're comparing two titles that show u a lot in our data, "teach" and "chemistry tutor". Logically, we know that these two titles probably have some type of relation, so we'd expect a higher dot product, as shown by the 0.449.

# %%
#title_vectors['teach']
dot_product = np.dot(title_vectors['teach'], title_vectors['teach'])
dot_product
#santiy check that dot product = 1 since they are the same thing
# Out:
# 1.0

# %% [markdown]
# This makes sense as a sanity check, so now we can also check the dot product of 'teach' and 'teach', which should be 1.

# %%
#loop over all keys in dict 

ranked_titles = {}


#can also use title_vectors.keys() 
for key in title_vectors:
    ranked_titles[key] = np.dot(title_vectors['food'], title_vectors[key])

# note: might not work if the word is not in our dictionary (the new pangea one not gensim)

# %% [markdown]
# This is also true, and now we're ready to move on to creating a new dictionary called "ranked_titles", that contains the literal title vector (this will, in future state, be each new title that a user inputs), as well as its similarity to other titles that are already in our ddatabase.

# %%
import operator
sorted_title_vecs = sorted(ranked_titles.items(), key=operator.itemgetter(1), reverse=True)

# %% [markdown]
# Next, we want to sort the title vectors by relevance--the higher the dot product, the more we care about that vector.

# %%
sorted_title_vecs[:30]
# Out:
# [('food', 1.0000001),
#  ('food photography', 0.7063276),
#  ('food delivery thanksgiving', 0.6528243),
#  ('deliver dining hall food', 0.6489846),
#  ('farm fresh meal', 0.54369897),
#  ('rice cooking pot', 0.5030476),
#  ('cooking', 0.47695595),
#  ('drink wine', 0.47675544),
#  ('chef prepared meal prep', 0.47417408),
#  ('meal credit', 0.46516),
#  ('homecooked dinner', 0.46060634),
#  ('tomato soup recipe', 0.44682276),
#  ('grocery runs', 0.42736563),
#  ('buy groceries', 0.4250207),
#  ('grocery shopping', 0.4146102),
#  ('pet cleaning services', 0.4097092),
#  ('meal swipes', 0.40529132),
#  ('private cook', 0.39881307),
#  ('keto diet daily menu', 0.39766154),
#  ('even delicious cookies', 0.38736588),
#  ('delicious cookies', 0.3863588),
#  ('professional pet bathing services', 0.38212496),
#  ('help setting farmers market sun', 0.37188083),
#  ('feed cuddle cat', 0.35799968),
#  ('mediterranean cooking class', 0.3564884),
#  ('pet photography', 0.35361582),
#  ('pet care advice', 0.35287824),
#  ('cooking lessons', 0.35078347),
#  ('chicken nuggets', 0.34986973),
#  ('personal pet day', 0.3481158)]

# %% [markdown]
# Finished:
# - built a recommender system that takes in a user inputted title and compares it with every title that we have in our database
#
# Next steps:
# - need to ask John what type of output / JSON payload he wants for this (titles? titles with how well they match? top 10? top 50? ranked list? very good match???)

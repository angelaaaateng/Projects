# %% [markdown]
# ## Recommender System - Marketplace Matching
#
# In this notebook, we will:
# - Clean textual data from user-input verbatim posts
# - Use a Word2Vec model to calculate document similarities
# - Sort the most similar user input to our training data in order to recommend similar products
# - Save this model in a format that allows us to refresh the testing data
#
# The goal of this project is to create a recommender system to help Pangeans find the right "project" for them, given their profile information. Here, we are using legacy data that is from Pangea V2, when Pangeans were allowed to post services and requests, as well as purchase items on the platform. We are using the User-Inputted Titles to suggest similar services, or in V3, similar "projects".

# %%
'''Importing Libraries'''
import numpy as np
import pandas as pd

import sys
from pandas import DataFrame

import json
from pandas.io.json import json_normalize


import matplotlib.pyplot as plt
# %matplotlib inline 
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

from gensim import corpora
from collections import defaultdict
from pprint import pprint

from gensim.models.word2vec import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile

from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.test.utils import common_texts

import re
from sklearn.feature_extraction.text import CountVectorizer

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
nltk.download('stopwords') ###
from nltk.tokenize import RegexpTokenizer

import gensim 
from gensim.models import KeyedVectors
import gensim.downloader as api

from operator import itemgetter, attrgetter

from gensim.models.doc2vec import Doc2Vec

import os, sys

from operator import add

from sklearn.preprocessing import normalize

import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from adjustText import adjust_text

from sklearn.manifold import TSNE

import pickle

import json
from pprint import pprint
from pandas.io.json import json_normalize

import operator

import csv

import string
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/angelateng/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
'''Loading the model'''
model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary = True)

# %%
'''Vectorize and store existing titles in legacy Pangea database'''
def vectorize_and_store_existing_titles(): 
    raw = pd.read_csv("allPostData.csv", header=0);
    titles = raw['title'];
    post_titles = [title for title in titles];
    post_titles = set(post_titles); 
    tokens = [[word for word in title.lower().split()] for title in post_titles];
    clean_words = [[word.translate(str.maketrans('', '', string.punctuation)) for word in title] for title in tokens]
    #print(clean_words)
    #clean_words = [[word for word in title if word.isalpha()] for title in tokens];
    #tokenizer = RegexpTokenizer(r'\w+')
    
    stoplist = set(stopwords.words('english'));
    titles_nostopwords = [[word for word in title if word not in stoplist] for title in clean_words];   
    filtered_word_list = [[word for word in title if word in model.vocab] for title in titles_nostopwords];
    dictionary = dict(zip(post_titles, filtered_word_list))
    vectorized_titles = pd.DataFrame(columns=["Titles", "Vectors"])
    for title in post_titles: 
        word_vecs = [model[word] for word in dictionary[title]]
        if len(word_vecs) == 0:
            title_vec = [np.zeros(300)]
        else: 
            title_vec = normalize(sum(word_vecs).reshape(1, -1))
        vectorized_titles = vectorized_titles.append({'Titles': title, 'Vectors': title_vec}, ignore_index=True)
    vectorized_titles.to_pickle("/Users/angelateng/Google_Drive/SharpestMinds_dropbox/SharpestMinds/vectorized_titles.pkl")
    return(vectorized_titles)

# %%
'''Print a dataframe to show how these titles and their vectors will be saved'''
'''Also note that we are saving the df with the original raw (not cleaned) titles'''
vectorize_and_store_existing_titles()
# Out:
#                                            Titles  \
# 0                                 Spiritual Talks
# 1    Design The Coolest Debit Card For Kids/Teens
# 2                         App Development Lessons
# 3                              Campus Ambassador
# 4                               Remove Car Stereo
# 5                                    Matcha buddy
# 6                  Fujifilm Instax Mini Camera 25
# 7                                  Melee Tutoring
# 8                                 Overwatch coach
# 9                             Housekeeping Wanted
# 10                                 I'll be friend
# 11                      Play League of Legends <3
# 12                            tech interview prep
# 13                                 Recital Poster
# 14                              Smash 64 Practice
# 15                                LinkedIn Advice
# 16                                         Poetry
# 17                                    3 Head Lamp
# 18                                     Desk Lamps
# 19                                SAT Math Tutor
# 20                Official Event: Munchies Night!
# 21                                    raf simons
# 22                           Custom Love Song 😍😍😍
# 23                   Organize blue-ray collection
# 24                    Looking For German Tutoring
# 25                                  Dance Lessons
# 26                                 Jalapeno chips
# 27                                Web Development
# 28        Software Engineer needed for small proj
# 29                           Video making lessons
# ..                                            ...
# 711                                    Dog Walker
# 712                                Ride To Boston
# 713                                     Bartender
# 714                        Melee Practice Partner
# 715                                     Headshots
# 716                                   Beat making
# 717                            Programming Advise
# 718                  Super Smash Bros Melee Tutor
# 719                             Guided Meditation
# 720                               Fortnite Coach
# 721                                    COD Editor
# 722                             Biology Tutoring
# 723                                   PoGo Walker
# 724                            Personal organizer
# 725                             Paracord Bracelet
# 726                                      Laundry
# 727                             Marketing Lessons
# 728                                          Food
# 729                                   LaTex Tutor
# 730                               Origami Lessons
# 731                               Stickers needed
# 732                Learn Special Meme Techniques
# 733                    Lessons On App Prototyping
# 734                                Bring me bajas
# 735                             HTML email deisgn
# 736                         Freelance Photography
# 737                              CVS Picker Upper
# 738                          Need Help In History
# 739                                   Pet Sitting
# 740                                    Chem Tutor
#
#                                                Vectors
# 0    [[0.10162811, 0.051215217, 0.074616425, -0.027...
# 1    [[-0.06146582, 0.02307342, 0.050308917, 0.1127...
# 2    [[0.024453294, -0.02666793, -0.011280811, -0.0...
# 3    [[0.009185634, 0.018454658, 0.1293173, 0.00410...
# 4    [[0.006371396, 0.02385082, -0.0422105, -0.0206...
# 5    [[0.005861206, -0.031119319, 0.058747493, 0.13...
# 6    [[-0.023258874, 0.034682952, 0.015668174, 0.02...
# 7    [[0.11666875, 0.05078485, 0.022796279, 0.00778...
# 8    [[-0.027847748, -0.020765299, -0.0050430014, -...
# 9    [[0.0006252811, 0.08929014, 0.002251012, -0.06...
# 10   [[0.015295482, -0.031769928, -0.025813065, 0.0...
# 11   [[0.008193443, 0.045203872, 0.060799398, 0.041...
# 12   [[-0.00812811, 0.11060138, -0.057936218, -0.00...
# 13   [[0.057445057, 0.024767978, 0.0071285986, 0.03...
# 14   [[0.062727526, 0.018316587, -0.04743604, -0.00...
# 15   [[-0.034055714, -0.05297721, -0.005957001, 0.0...
# 16   [[0.0011733018, -0.008129656, 0.040844653, 0.0...
# 17   [[0.005498059, 0.014315701, 0.034959357, 0.021...
# 18   [[-0.0071875113, 0.029439645, -0.058778983, 0....
# 19   [[0.08019597, 0.0027660362, 0.042348966, 0.094...
# 20   [[-0.0021254965, -0.035582386, -0.023813434, 0...
# 21   [[-0.031609986, 0.0237785, -0.002975694, 0.083...
# 22   [[0.05952203, -0.06517673, -0.019530311, 0.083...
# 23   [[0.0002485228, 0.0914978, -0.020737845, 0.057...
# 24   [[0.03309645, 0.14562438, 0.014327279, 0.07067...
# 25   [[0.07197459, -0.040448528, 0.09319024, 0.0232...
# 26   [[-0.06908187, -0.08575681, 0.14122649, 0.1837...
# 27   [[-0.0029527857, -0.02281698, -0.027011279, -0...
# 28   [[0.001173173, 0.013858106, -0.013720624, -0.0...
# 29   [[0.017601628, 0.041898996, 0.046152107, -0.00...
# ..                                                 ...
# 711  [[0.056333717, -0.0380877, -0.09897714, 0.0760...
# 712  [[-0.09815242, -0.038097166, -0.039987102, 0.1...
# 713  [[-0.0146799665, -0.09691628, -0.016318992, 0....
# 714  [[0.09075975, -0.024231423, -0.0005425578, -0....
# 715  [[-0.011617748, 0.039382197, 0.0022808856, -0....
# 716  [[-0.015095135, 0.100170486, 0.09196207, -0.03...
# 717  [[-0.08503098, -0.0038664015, 0.064609215, 0.0...
# 718  [[0.06345864, -0.0020579502, 0.007223825, 0.02...
# 719  [[0.038705874, 0.0776144, 0.019609414, 0.06643...
# 720  [[-0.017795563, 0.026209364, 0.08101076, -0.04...
# 721  [[-0.069787085, -0.040290825, -0.06556699, 0.0...
# 722  [[0.02496585, 0.059411217, 0.0123890685, 0.100...
# 723  [[0.098822035, -0.0851182, -0.098243, 0.086855...
# 724  [[0.09288177, -0.03567334, 0.038201373, -0.036...
# 725  [[-0.05443361, -0.11862419, -0.0069325822, 0.1...
# 726  [[-0.05478974, 0.07229652, -0.05835594, 0.0382...
# 727  [[0.08399147, -0.0051044542, 0.011833052, -0.0...
# 728  [[-0.06801747, 0.06180082, -0.062166505, 0.133...
# 729  [[0.0619012, -0.0149769895, -0.07452506, 0.088...
# 730  [[0.08714361, -0.008696967, 0.026612718, 0.013...
# 731  [[0.0613278, 0.027393484, 0.010426326, 0.02688...
# 732  [[0.09193586, 0.03115794, -0.0048417277, 0.100...
# 733  [[0.020253977, -0.031405043, -0.050369438, 0.0...
# 734  [[-0.023648534, 0.029506428, 0.03384561, -0.02...
# 735  [[0.0036273915, -0.005392332, -0.019853143, 0....
# 736  [[-0.008616091, -0.00049210835, -0.08822161, 0...
# 737  [[0.01778612, -0.03279248, -0.06992833, 0.1205...
# 738  [[0.034072954, 0.067304604, 0.025347782, 0.039...
# 739  [[0.06251353, 0.06792043, -0.023814676, 0.1171...
# 740  [[-0.028732741, 0.04354651, 0.0032809014, 0.11...
#
# [741 rows x 2 columns]

# %%
'''Read a JSON file when a new user pings with a request'''
with open('firstPost.json') as fresh_data:
    user_post = json.load(fresh_data)

'''Vectorize each new title as a user/student/company creates a new post'''
def vectorize_new_title(user_post):
    #ranked_titles_load = pd.read_csv("./ranked_titles.csv")
    json_df = pd.DataFrame.from_dict(json_normalize(user_post), orient='columns')
    title = json_df["title"][0] #--> added [0] because json_df["title"] was still in pd.Series form
    json_tokens = [word for word in title.lower().split()]
    #json_clean_words = [[word for word in title.lower().split()] for title in post_titles];
    json_clean_words = [word.translate(str.maketrans('', '', string.punctuation)) for word in json_tokens]
    #print(json_clean_words)
    
    stoplist = set(stopwords.words('english'));
    json_titles_nostopwords = [word for word in json_clean_words if word not in stoplist]   
    json_preprocessed = [word for word in json_titles_nostopwords if word in model.vocab]   
    json_title_vectors = {}
    json_vectorized_title_df = pd.DataFrame(columns=["Titles", "Vectors"])
    json_word_vecs = [model[word] for word in json_preprocessed]
    if len(json_preprocessed) == 0:
            json_title_vec = [np.zeros(300)]
    else: 
        json_title_vec = normalize(sum(json_word_vecs).reshape(1, -1))
    json_vectorized_title_df = json_vectorized_title_df.append({'Titles': title, 'Vectors': json_title_vec}, ignore_index = True)
    #export_csv = json_vectorized_title_df.to_csv (r'/Users/angelateng/Dropbox/AMBER/SharpestMinds/ranked_titles.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
    if not os.path.isfile('/Users/angelateng/Google_Drive/SharpestMinds_dropbox/SharpestMinds/ranked_titles.csv'):
        json_vectorized_title_df.to_csv (r'/Users/angelateng/Google_Drive/SharpestMinds_dropbox/SharpestMinds/ranked_titles.csv', index = None, header=True)
    else:
        json_vectorized_title_df.to_csv (r'/Users/angelateng/Google_Drive/SharpestMinds_dropbox/SharpestMinds/ranked_titles.csv', mode='a', index = None, header=False)
    
    return(json_vectorized_title_df)

# %%
'''Append new user-post title to csv'''
vectorized_title = vectorize_new_title(user_post)
print(vectorized_title)
# Out:
#                   Titles                                            Vectors
# 0  Teach Me How To Cook!  [[-0.022974137, 0.010501054, 0.05975248, 0.041...

# %%
print(user_post)
# Out:
# {'address': {'components': {'city': 'Providence', 'country': 'US', 'county': 'Providence County', 'number': '158', 'state': 'RI', 'street': 'University Ave', 'zip_code': '02906'}, 'formatted': '158 University Ave, Providence, RI 02906, USA'}, 'archived_status': 'live', 'category': 'Cooking', 'content_type': 'service', 'created_at': {'$reql_type$': 'TIME', 'epoch_time': 1505340466, 'timezone': '+00:00'}, 'description': "I'm trying to broaden the repertoire of culinary dishes I can make. Please help! I'm surviving on chicken and pasta rn... I'll buy the ingredients.", 'id': '-Kty6gXaY-_wgIheV3LS', 'last_modified': '2018-09-07T23:08:39.964Z', 'location': {'$reql_type$': 'GEOMETRY', 'coordinates': [-71.3877064, 41.8342705], 'type': 'Point'}, 'owner_id': 'RHCWoC5WnSTXi0JWJadv18ejPwy1', 'payment_type': 'fixed', 'photos': [], 'post_type': 'request', 'price': 25, 'price_type': 'flexible', 'status': 'legacy', 'title': 'Teach Me How To Cook!', 'visibility': 'public'}

# %%
'''Load the current titles in the Pangea database, and then rank them by similarity to the latest user query'''
def rank_existing_titles(vectorized_title):
    ranked_titles = {}
    other_titles = pd.read_pickle("./vectorized_titles.pkl")
    #print(other_titles)
    for index,row in other_titles.iterrows():
        ranked_titles[row['Titles']] = sum(row['Vectors'][0]*vectorized_title['Vectors'][0][0]) # --> did the dot product using sum() and * because np.dot was behaving weirdly for some reason. Now it seems to work! 
    sorted_title_vecs = sorted(ranked_titles.items(), key=operator.itemgetter(1), reverse=True)
    return(sorted_title_vecs)

#should this also be named ranked titles? or should we rename this line? since we're 
#already loading them in the cell above ??

# %%
rank_existing_titles(vectorized_title)
# Out:
# [('Teach Me How To Cook!', 1.0000000256776254),
#  ('Teach me how to cook quick meals!', 0.8501101096892398),
#  ('Teach how to prepare steaks ', 0.7433686636395578),
#  ('Private cook', 0.7177446654708319),
#  ('Private Cook ', 0.7177446654708319),
#  ('Cooking lessons', 0.6707953416986925),
#  ('Cooking Lessons', 0.6707953416986925),
#  ('Cooking Lessons ', 0.6707953416986925),
#  ('Cooking', 0.6634962084033305),
#  ('Teach me how to play piano', 0.6475645409999515),
#  ('Teach how to make tea', 0.6299678694610975),
#  ('Culinary tutor', 0.5939296423903215),
#  ('Baking Lessons ', 0.5822712795805955),
#  ('Mediterranean Cooking Class', 0.5702011714132595),
#  ('Teach you how to shuffle', 0.5699134945516562),
#  ('Teach Me How To Solve Rubiks Cube', 0.55600204987811),
#  ('Brazilian Cooking Class', 0.5491360732714838),
#  ('Learn To Juggle!', 0.5355930420098503),
#  ('Chef Prepared Meal Prep', 0.5327085255917154),
#  ('Help me learn Pop/Stars dance', 0.5109324808180418),
#  ('Teach me meme culture', 0.5040128903044376),
#  ('Pretend Dad for Hire', 0.4948300821856719),
#  ('Rice Cooking Pot', 0.48751110356579375),
#  ('Math tutor', 0.4857890719771376),
#  ('Math Tutor', 0.4857890719771376),
#  ('Sm4sh Tutor', 0.4682695051464947),
#  ('Mariokart tutor', 0.4682695051464947),
#  ('Splatoon Tutor', 0.4682695051464947),
#  ('Mk8 Tutor ', 0.4682695051464947),
#  ('Piano classes (for beginners)', 0.4586191221903846),
#  ('Basic Painting Lessons', 0.44808969040366264),
#  ('SAT Math Tutor ', 0.4477572820490252),
#  ('Orgo lesson ', 0.4468142364597725),
#  ('Homecooked Dinner', 0.44181964852600686),
#  ('Learn To Harmonize', 0.44031284917832636),
#  ('Improv And Acting Lessons', 0.4380554126003062),
#  ('Beginner Chinese Lessons', 0.4368385652559823),
#  ('Chemistry Tutor', 0.4352458780910524),
#  ('tutor for transport', 0.43489484901886044),
#  ('Origami Lessons', 0.4332527334504448),
#  ('Homework help', 0.4317610373084335),
#  ('CS15 Homework Help', 0.4317610373084335),
#  ('Bosnian/Croatian Language Tutor ', 0.4309342216456571),
#  ('Self-Defense Lessons', 0.42962378564266146),
#  ('Singing Lessons', 0.4287468107938821),
#  ('Physics Tutor', 0.4283676953364193),
#  ('English Tutor', 0.4271095272365528),
#  ('Dance Lessons', 0.4242375539987506),
#  ('Learn Special Meme Techniques ', 0.4228609950455393),
#  ('Piano Lessons', 0.422019626010524),
#  ('Piano lessons', 0.422019626010524),
#  ('PHYS 0470 tutoring', 0.4177399899682541),
#  ('Basic Chinese Lessons ', 0.4172558781099269),
#  ('Beginner Chess Lessons 1', 0.4172014774947286),
#  ('Chem tutor ', 0.417191705162395),
#  ('Chem Tutor', 0.417191705162395),
#  ('Chinese Calligraphy lessons', 0.4167959899444895),
#  ('Baking Partner', 0.4130180135583714),
#  ('Spanish Tutor ', 0.4115105846424285),
#  ('Computer science lesson', 0.41132661648612157),
#  ('Crocheting Lessons ', 0.4108167329238199),
#  ('Math Tutoring', 0.41026411994835144),
#  ('Excel Training By an Expert', 0.4100829246426656),
#  ('Tutoring For Gov Lessons', 0.4097029969340724),
#  ('Basic Apma Tutoring ', 0.4087549670964563),
#  ('Violin Basics', 0.40868143648140176),
#  ('Farm Fresh Meal Prep! ', 0.4083216543799608),
#  ('Learn to erg', 0.40772320972874354),
#  ('Acting Lessons ', 0.4076244042792041),
#  ('Acting Lessons', 0.4076244042792041),
#  ('Painting Lessons', 0.4059738192934219),
#  ('Ukulele Lessons', 0.4038370509588276),
#  ('Babysit your plants', 0.40251656991699747),
#  ('Biology Tutoring', 0.4016307696840613),
#  ('Biology Tutoring ', 0.4016307696840613),
#  ('Psychology Tutoring', 0.4003184151958976),
#  ('Help Me Sell My Stuff!', 0.39985023283679766),
#  ('Bate Papo/Portuguese Lessons', 0.3954647486776679),
#  ('Korean Tutor', 0.3947873621427789),
#  ('Art tutoring', 0.392675175046179),
#  ('Basic Flamenco Guitar Lessons', 0.39201884146422117),
#  ('Eating Coach ', 0.3919413457999781),
#  ('French Lessons', 0.390401749436478),
#  ('LET ME VIDEOGRAPHY YOU DOING SOMETHING COOL', 0.3886656911975024),
#  ('German Lessons & Tutoring', 0.38664871592337136),
#  ('Tomato Soup Recipe', 0.384613732657499),
#  ('Chinese lessons', 0.3843312886763215),
#  ('Polish Dessert (budyń)', 0.3839515188489031),
#  ('Fortnite Lessons', 0.38281294160503876),
#  ('Prototyping/Wireframing Lessons', 0.38281294160503876),
#  ('Amharic lessons ', 0.38281294160503876),
#  ('Make me waffles', 0.38210519892675165),
#  ('Calc tutor', 0.3806446646439099),
#  ('Ukelele lessons', 0.37916045428823963),
#  ('Physics 160 tutoring', 0.3767876058340107),
#  ('Bike lessons', 0.3761394893590193),
#  ('French tutoring', 0.37593305840800895),
#  ('quesadilla from Joes.', 0.37542428343499523),
#  ('Board Games! (Teaching)', 0.3751373760338197),
#  ('Music Lessons', 0.3751216885445956),
#  ('music lessons!', 0.3751216885445956),
#  ('Help cleaning my house please!!!', 0.37392490598324457),
#  ('Biking Lessons ', 0.37263605952114176),
#  ('Mario kart Tutor', 0.3718346899736389),
#  ('Mario Kart Tutor', 0.3718346899736389),
#  ('Guitar Lessons', 0.37069923178160025),
#  ('Highschool Math', 0.36932433985202806),
#  ('Food Photography', 0.3682208793684367),
#  ('Smash 4 Tutor', 0.36693987983881016),
#  ('Golf Lessons', 0.36420303385057196),
#  ('Laundry help wanted', 0.3640176542653535),
#  ('looking for mario kart tutor', 0.36323285445335785),
#  ('Housekeeping Wanted', 0.3616239984951335),
#  ("Rubik's Cube Lessons!", 0.36155610514208547),
#  ('Tech Consultant/Programming Tutor', 0.3615247665379684),
#  ('Calculus Tutoring', 0.3613473446548596),
#  ('Viola Lessons', 0.36087802831661975),
#  ('Acapella Lessons', 0.35827311337925494),
#  ('Deliver dining hall food to you ', 0.35740180565210267),
#  ('Basic CS Lessons', 0.35726922146614015),
#  ('Driving lessons', 0.357187037757285),
#  ('Spanish Tutoring', 0.35691844400253103),
#  ('Spanish tutoring ', 0.35691844400253103),
#  ('American Sign Language Lessons', 0.3558192767048922),
#  ('Econ Lessons', 0.3554641743965874),
#  ('Korean lessons', 0.35471901958317176),
#  ('Tennis Lessons', 0.35383124213627326),
#  ('CS homework help', 0.35380656291215473),
#  ('Marketing Lessons', 0.3528942897594334),
#  ('Hitting lessons ', 0.35241173758049626),
#  ('Snowboarding Lessons', 0.35065220383171436),
#  ('A pretend boyfriend', 0.3500916922452202),
#  ('Neuro/CLPS Tutoring', 0.34996856702127843),
#  ('Rock-Paper-Scissors Tutoring', 0.34996856702127843),
#  ('Tutoring', 0.34996856702127843),
#  ('CS16 Tutoring', 0.34996856702127843),
#  ('Tutoring ', 0.34996856702127843),
#  ('Biol0800 Tutoring', 0.34996856702127843),
#  ('Econ Tutoring', 0.34938955373746694),
#  ('Take photos at BBQ', 0.34901852972689085),
#  ('Ballroom dancing lessons', 0.34897367312487404),
#  ('Skateboarding Lessons ', 0.348528715876796),
#  ('Please Buy Me A Ben & Jerry’s Ice Cream Cake!!!', 0.34815252075168246),
#  ('Debate Lessons', 0.34781024176072606),
#  ('Soccer Lessons', 0.34773557820570034),
#  ('Soccer Lessons ', 0.34773557820570034),
#  ('I want my dog to dress up like dis', 0.3473172060505476),
#  ('I Need Help In Physics', 0.3471779682849956),
#  ('Fitness instructor ', 0.34536036535973835),
#  ('Even More Delicious Cookies', 0.34287129962854124),
#  ('Help with case prep for consulting ', 0.3389186349149895),
#  ('Work wanted', 0.3388812681253057),
#  ('Smash Ultimate Tutor', 0.3379422383486599),
#  ('CS Tutor', 0.33758519624166183),
#  ('Cs tutor ', 0.33758519624166183),
#  ('Mario Kart Lessons', 0.3366643899682913),
#  ('Love and Life Advice 💕', 0.33562873562186724),
#  ('WW2 History Lessons', 0.3343141895450117),
#  ('Dinner', 0.3330296753217681),
#  ('Long Boarding Lessons', 0.33263714851818804),
#  ('Dinner buddy', 0.3323426415773838),
#  ('Corporate Finance Tutor ', 0.33224838251408073),
#  ('Laundry Help ', 0.33075946306865944),
#  ('Make cookies', 0.32889019859311475),
#  ('LaTex Tutor', 0.32816899349381856),
#  ('Melee tutor', 0.3273837214142077),
#  ('R Tutoring', 0.32566303459375945),
#  ('Photoshopping Lessons', 0.32545481075499083),
#  ('Delicious Cookies', 0.32420826146972104),
#  ('Film shoot participants!', 0.3239478746942268),
#  ('Feed and Cuddle Cat', 0.3228725789671927),
#  ('Video making lessons', 0.32273658872179567),
#  ('Lunch buddy', 0.3223320662157221),
#  (' Food', 0.3214565657622188),
#  ('Prototyping Lessons ', 0.3200046414458484),
#  ('Camp counselor [Summer]', 0.31913439862523774),
#  ('Portuguese classes', 0.3188343437162757),
#  ('VSCO Tutorial', 0.31818961670160206),
#  ('Hang Out With Some Cool Guys!', 0.31399888116531827),
#  ('Programming Advise', 0.3131123762814241),
#  ('Latin Translation And Tutoring', 0.3127124553484464),
#  ('Lessons On App Prototyping', 0.3124481165755242),
#  ('Math hw', 0.3121262643896898),
#  ('SAT Tutoring', 0.31187673518888914),
#  ("I'll be a really cool friend", 0.3118385091960221),
#  ('League Lessons', 0.30962493403296776),
#  ('Simple Photography', 0.3070161074974038),
#  ('Buy Me Groceries', 0.30699189562255924),
#  ('Free Brownies', 0.3068077012746926),
#  ('Organize blue-ray collection', 0.3066998388829347),
#  ('App Development Lessons', 0.3064129615779905),
#  ('Matcha buddy', 0.3062652236686745),
#  ('Smash 4 Tutoring', 0.3051044973907153),
#  ('Lessons On Technical Interview ', 0.3050870304177806),
#  ('Looking to take care of a bulldog!', 0.30429120990652336),
#  ('Adobe Illustrator Help', 0.30369961372670673),
#  ('Idea Help', 0.3018559082097454),
#  ('Mason Jars', 0.3014624732641096),
#  ('Ice Cream Sandwiches', 0.3007665051515005),
#  ('Help with Anthropogy', 0.2974565560505198),
#  ('Licensed Bartender', 0.29651335934217116),
#  ('Unity lessons', 0.2949682837409),
#  ('Tips for Writing a Paper', 0.2946847098349963),
#  ('Hip Hop Lessons ', 0.2942839110114619),
#  ('Help Moving A Bed ! ', 0.294059451162866),
#  ('Final Cut Pro Lesson', 0.29295754821782793),
#  ('Waterpolo Tutoring', 0.2903081319817602),
#  ('Singing', 0.29007116779712305),
#  ('Melee Lessons!', 0.28770705236456706),
#  ('Accounting Help', 0.28647596699283895),
#  ('Meal Credit', 0.2861430784618051),
#  ('French Tuition', 0.28609483363641175),
#  ('Motivational Pep Talk', 0.2858403367195024),
#  ('Boba friend', 0.28510308952732544),
#  ('On-Campus Meal Swipes', 0.28508941758673245),
#  ('Make Brandy Alexander Pie', 0.2839343350137824),
#  ('CS Tutoring ', 0.2833837668782735),
#  ('Novice running buddy', 0.2832774652620813),
#  ('Recruiting Help', 0.28312674460687504),
#  ('I wanna get good at smash', 0.2813810863337949),
#  ('Help Setting up for Farmers Market Sun', 0.28014041847268345),
#  ('Poetry', 0.27978949711619805),
#  ('Looking for a guinea pig babysitter ', 0.2788657070229874),
#  ('Life Coach', 0.2782940948511623),
#  ('Sketch tutorials', 0.27816585664470495),
#  ('Dog Care', 0.2780975633363596),
#  ('Ride In A Porsche Cayenne', 0.2761684358434877),
#  ('Need Help In History', 0.27554526959113446),
#  ('Looking For German Tutoring', 0.2751467849470828),
#  ('Table Saw Help', 0.2745324673292089),
#  ('Birthday Planner Wanted', 0.2744851356965796),
#  ('cuddler', 0.27424578714271775),
#  ('LinkedIn Help', 0.27401281998822924),
#  ('Bring me bajas', 0.27285263096337076),
#  ('Dog Sitter Over Thanksgiving', 0.27283837283348394),
#  ('Breakdance sessions', 0.27249661450355234),
#  ('QUICK SELL AIR FORCE 1’s', 0.2723677312710606),
#  ('Boba buddy', 0.27151510514227084),
#  ('Boba Buddy', 0.27151510514227084),
#  ('Guided Meditation', 0.27150184909487507),
#  ('Sewing a Button', 0.2715000152303926),
#  ('Freelance Photography', 0.2710194281354461),
#  ('Investment basics (FOREX) ', 0.27023940003027747),
#  ('Pet Care Advice', 0.2691828264984224),
#  ('Selling Clothes', 0.2687978642190956),
#  ('Super Smash Bros Melee Tutor', 0.26872545385191415),
#  ('Melee Tutoring', 0.2687000658133911),
#  ('Find Maltipoo Puppies ', 0.26866198329526014),
#  ('Public speaking coach', 0.2674233468468685),
#  ('Computer Science ', 0.26626908880052724),
#  ('Need Help With Paper Editing', 0.266264751297399),
#  ('Help with life problems ', 0.26471394616851285),
#  ('Help hanging lights in my common room', 0.26428228630720696),
#  ('Coffee friend', 0.2636704536009802),
#  ('Fitness motivator', 0.26362122663613263),
#  ('Organize my iPhone', 0.26339083768129967),
#  ('Gym Buddy', 0.26328726147517045),
#  ('Professional Pet Bathing Services', 0.261986380326789),
#  ('Pet Photography ', 0.26198428525844975),
#  ('Beauty Blender Holders', 0.2616005233880969),
#  ('Plan a fun night/weekend in Boston!', 0.260940299896788),
#  ('Behavioral Interview Prep ', 0.2609110240264272),
#  ('Keto Diet Daily Menu', 0.26087842439801534),
#  ('Bio Tutoring', 0.2606519306041264),
#  ('Helping Brown Esports', 0.26060688902362017),
#  ('Vegetarian/Vegan Diet Advice', 0.2599625147722122),
#  ('Get A Startup Job', 0.2566226006904344),
#  ('Bang Wo Shuo Zhongwen, Help Chinese', 0.2560381033601331),
#  ('Badminton Buddy', 0.2558574218655849),
#  ('Bartender', 0.25554137918675224),
#  ('Pokemon lets go', 0.25521877768574086),
#  ('Running Buddy/Running Help', 0.2551592307240753),
#  ('Bed Bath & Beyond Drawers', 0.25466442867832484),
#  ('Custom Poetry ', 0.2539967286643332),
#  ('Custom Poetry', 0.2539967286643332),
#  ('Eliminate Russell Carey & Replace Him With a Robot', 0.25387888545725446),
#  ('MCM Tutoring', 0.253631710738091),
#  ('Venture Help', 0.25290298997651917),
#  ('Model Making Help', 0.25219221411126114),
#  ('Chicken nuggets', 0.2497498378477303),
#  ('Food Delivery On Thanksgiving', 0.2493518978890279),
#  ('hang up my TV mount', 0.2492245006014855),
#  ('Fix my bike', 0.24892112813176936),
#  ('will to live', 0.24850607815687908),
#  ('Photography Sessions', 0.24814546864627118),
#  ('Performance of “Never Wanna Give you Up”', 0.24737055284180087),
#  ('basic guitar chords', 0.24704923839431103),
#  ('Book design', 0.24636703442388352),
#  ('Toon Link Brawl Tutoring ', 0.24600924388369094),
#  ('Custom Love Song 😍😍😍', 0.24520894605859667),
#  ('Dating counselor ', 0.24495904802472523),
#  ('Will Drink Wine With You ', 0.24412306014977503),
#  ('Photography ', 0.2434872993922994),
#  ('Photography!!', 0.2434872993922994),
#  ('Photography', 0.2434872993922994),
#  ('SAS / SQL Tutor', 0.2426720449258255),
#  ('car photography', 0.2417320849994269),
#  ('Looking to buy printer', 0.24155794594889812),
#  ('Recycling Tips', 0.24155705501766533),
#  ('Food delivery!', 0.24096700471636723),
#  ('Pet Cleaning Services', 0.24056739437446595),
#  ('Filmmaking 🎥', 0.2405541651700105),
#  ('Art', 0.24043978260579024),
#  ('Whatever ', 0.24006040693677733),
#  ('Event Photography', 0.23919606975374563),
#  ('Looking for Dog Sitter!', 0.23864586219178818),
#  ('Spanish tutoring/conversation practice', 0.2382848844849832),
#  ('Photographer Wanted', 0.23822409060426253),
#  ('CAD Help', 0.2380526711363018),
#  ('Orgo Kit', 0.23684624273346344),
#  ('Back massage ', 0.23631619139655413),
#  ('Campus Ambassador Program', 0.23631225867529793),
#  ('Someone to vent too', 0.23566308232796018),
#  ('Quiz me on notes ', 0.2354387082031053),
#  ('Materials engineer ', 0.2353425532194251),
#  ('Beat making', 0.23465207788603948),
#  ('Massage (30-minute)', 0.2330821686859963),
#  ('Resume and/or Cover Letter Help', 0.23264191332054907),
#  ('League Of Legends Mentor', 0.2322357319171715),
#  ('Need Somthing ? ', 0.2311674359978042),
#  ('Halloween Costume Ideas', 0.23112663985602921),
#  ('CS Debugging Lessons', 0.2310999724076055),
#  ('Free Cookies ', 0.23065102926352665),
#  ('💜tink knit hats & scarves for a cause💜', 0.23053017876031845),
#  ('Catsitters Wanted', 0.22977608606242939),
#  ('Dogsitter Wanted', 0.22977608606242939),
#  ('Holiday parties and dinner ', 0.22927434195275964),
#  ('LinkedIn Recruiter (remote)', 0.22901894850338067),
#  ('Gimme Anime To Watch', 0.22899212345464548),
#  ('Software Design Internship', 0.22873904469719264),
#  ('Clean room', 0.22867646198551483),
#  ('Moving help', 0.22772649241778709),
#  ('Moving Help', 0.22772649241778709),
#  ('Help moving', 0.22772649241778709),
#  ('Pet sitter ', 0.2270602833252724),
#  ('Laundry service ', 0.22608595660506126),
#  ('pump u up abt ur dog', 0.22591343074117276),
#  ('Cleaning', 0.22566577420775502),
#  ('Cleaning ', 0.22566577420775502),
#  ('Dulcimer player', 0.2255326975329126),
#  ('Someone to set me up with a boy ', 0.22519059989247125),
#  ('Real estate photography', 0.22485634626983142),
#  ('create youtube channel art for me', 0.2241677618126232),
#  ('Stuff', 0.22413196396684043),
#  ('Translator', 0.22318791993245668),
#  ('clean my guinea pig cage', 0.2231643080502863),
#  ('General Stylist', 0.2230937790607186),
#  ('Data Science Intern', 0.22284093298785024),
#  ('Looking For Animator', 0.222131255484328),
#  ('Do my Laundry', 0.22027519837320142),
#  ('Laundry', 0.22027519837320142),
#  ('Laundry ', 0.22027519837320142),
#  ('Jalapeno chips', 0.22012919474059345),
#  ('Animator', 0.22011401910219774),
#  ('Clean out my garage', 0.21884776695833352),
#  ('Robin Williams Good Will Hunting Experie', 0.21801635583699408),
#  ('Gym Partner', 0.2147346638498675),
#  ('Heart glow stick', 0.21419610797283894),
#  ('Zero Waste Pop Up Shop', 0.21385929556655014),
#  ('Lil Ducky', 0.21345712845959497),
#  ('Banquet Night Specialist', 0.21314700780919793),
#  ('Car wax', 0.21290521842638555),
#  ('Anime Buddy', 0.21203030441120063),
#  ('tennis stringing ', 0.2115550899687264),
#  ('Explore RI', 0.21138014765119806),
#  ('Help Frame Two Canvas Paintings! ', 0.2107544860505186),
#  ('Photography / Portraits', 0.2106641004256744),
#  ('Software Engineer needed for small proj', 0.21035991410030874),
#  ('Essay Editing', 0.2097338967905671),
#  ('Essay Editing ', 0.2097338967905671),
#  ('Dog walker ', 0.2095062573715154),
#  ('Dog walker', 0.2095062573715154),
#  ('Dog Walker', 0.2095062573715154),
#  ('Personal therapist ', 0.2093666931664302),
#  ('Pet walker', 0.20848894166238097),
#  ('Shopping buddy', 0.20847643716092534),
#  ("I'll be friend", 0.20810507546264034),
#  ('Technical Interview Help', 0.20792259546215064),
#  ('React Native Developer', 0.2074955703581054),
#  ('Indesign Tutoring', 0.20675249861551492),
#  ('Cat Sitter', 0.20669086196028275),
#  ('Free Cupcake ', 0.2052555659746531),
#  ('Personal organizer', 0.20403034472337822),
#  ('tech interview prep', 0.20365095331101202),
#  ('Tech interview Prep', 0.20365095331101202),
#  ('Caricature Artist ', 0.20337332722692736),
#  ('Literature Editing', 0.2025580883434941),
#  ('Copywriter fo my website ', 0.2009695432789158),
#  ('Spiritual Guidance', 0.2007733752278682),
#  ('Tax Prep', 0.2007526743550443),
#  ('Fortnite Coach ', 0.20075118876718534),
#  ('Finance Interview Practice', 0.20036607628162528),
#  ('Research Buddy', 0.20030509233231442),
#  ('Will chance you for brown ', 0.20022833560483377),
#  ('Hearthstone coaching', 0.20011497501803888),
#  ('Fashion Stylist', 0.19960800701824155),
#  ('Google Home', 0.19934274886827552),
#  ('Composition and music theory', 0.19868038211882322),
#  ('Graphic Design work', 0.1983348261712763),
#  ('Bed Raises', 0.1976074439959845),
#  ('VBA Coding Advice', 0.1973512999930449),
#  ('Let’s play hearthstone', 0.19733006842989198),
#  ('Programmer Needed!! web/app platform!', 0.1968254198741306),
#  ('Dog Sitting / Walking ', 0.19605253777785947),
#  ('Running Buddy', 0.19532128732839737),
#  ('Personal coach', 0.19399161927833575),
#  ('Dog walking', 0.19385379900768385),
#  ('Classical Music Recommendations', 0.19329020761279025),
#  ('Art Pieces', 0.1932565060330944),
#  ('Play League of Legends <3', 0.19284719744497636),
#  ('Social Detective ', 0.1927724489667071),
#  ('Fine Arts Printing ', 0.19269148738112563),
#  ('Super Smash Bros. Melee coaching', 0.19224323552896294),
#  ('LinkedIn Advice', 0.19162524472677944),
#  ('Portrait Photography', 0.19147544260385985),
#  ('Desk Lamps', 0.19121194986155388),
#  ('Santa Cruz Bigfoot Longboard', 0.1911191520309785),
#  ('Dog Sitting', 0.19022446014685102),
#  ('Lathe machining', 0.190040750082062),
#  ('Photography (Senior Pics, Blog, Company, etc)', 0.18903605394302758),
#  ('Play Melee', 0.18861914687863646),
#  ('LED Book Light ', 0.18859642271650046),
#  ('Spiritual Talks', 0.18836956472364363),
#  ('consultant advice ', 0.1882824747021914),
#  ('Portfolio Help', 0.18810143696919113),
#  ('Grocery Runs', 0.18733220832177722),
#  ('Event Planner', 0.18706842786912148),
#  ('Wordsmith ', 0.1857107183300286),
#  ('TV Show Recommendations ', 0.18549501666780088),
#  ('Buddy', 0.1850299936968156),
#  ('Social media help ', 0.18496353304374225),
#  ('Ice Cream Delivery', 0.18495786926814617),
#  ('Behavioral Interview Practice ', 0.1847666228795788),
#  ('Essay Peer Reviewing ', 0.18418629251559082),
#  ('Hellux Carry', 0.18273338855630072),
#  ('Smash 4 buddy', 0.1825495508738868),
#  ('Offering Gphx Advice', 0.18254020121310077),
#  ('Campus Ambassador ', 0.18142252247525903),
#  ('Furniture Design', 0.18096653651764427),
#  ('Workout Plan', 0.18091906930521873),
#  ('Hair trim ', 0.18069540586364496),
#  ('Beatles Sound Alike Songs', 0.18066976250509015),
#  ('Mario Kart', 0.1804360882997571),
#  ('Claymation', 0.17982210115746966),
#  ('Blog writer ', 0.17928376116321942),
#  ('Massages!', 0.17866218671264278),
#  ('looking to pet a dog', 0.17857896743407764),
#  ('Walnut For Cheap', 0.1783890206174874),
#  ('Marketing Advice', 0.1782390695561844),
#  ('Metal Shop Cleaner', 0.17772538922918102),
#  ('Set me up with a boy ', 0.17765541729966117),
#  ('Pet Sitting', 0.177496600394079),
#  ('Landscape Photography ', 0.17728973406394744),
#  ('Personal pet for a day ', 0.17728120160859362),
#  ('Art Commissions', 0.1751816953769776),
#  ('Start Up Consulting ', 0.17498851578130825),
#  ('SAS Advice! ', 0.17490609279332148),
#  ('Fix Zipper', 0.17488435517998369),
#  ('Breakfast to your door (Kappa Delta)', 0.17462069718385465),
#  ('Videographer', 0.1744885934708691),
#  ('Personal Trainer', 0.17415849274698303),
#  ('Need Fabrics', 0.17325144004820459),
#  ('Marketing Intern ', 0.17301334274930014),
#  ('Free fantasy baseball advice', 0.17300409677000061),
#  ('Trumpet or drums', 0.17252126726424422),
#  ('Wax Ring ', 0.17230778338898745),
#  ('Basic Web Development', 0.17211889160955707),
#  ('Help Your Tinder Profile', 0.17182002210370229),
#  ('Voice Acting', 0.17164943615034645),
#  ('Guinea Pig Thanksgiving Petsitter', 0.1714786716997878),
#  ('Squirrels', 0.17141166175417766),
#  ('Recital Poster', 0.17135223471609606),
#  ('Cupcake Delivery', 0.1713003477490247),
#  ('Palm reading ', 0.17055559144046128),
#  ('Remove Car Stereo', 0.1702947339615548),
#  ('Roll Up Electronic Drum Kit', 0.16852203965663648),
#  ('Vaseline ', 0.16850159954543642),
#  ('Data Science ', 0.1677844941868898),
#  ('Website Build', 0.1677143033491575),
#  ('Fantasy Baseball Advising', 0.16763671121657353),
#  ('Career Advice In Consulting', 0.16727632185313723),
#  ('Looking For Social Media Coordinator ', 0.16607562948712484),
#  ('Resume + Cover Letter ', 0.1659612003336406),
#  ('Ride To Boston', 0.1656653928034757),
#  ('Move Sofa ASAP', 0.16503024823339274),
#  ('Grocery shopping', 0.16461745502920166),
#  ('Tarot Card Readings', 0.16439060644461279),
#  ('Financial Accountant', 0.16430570971715497),
#  ('Official Event: Munchies Night!', 0.16387672655469032),
#  ('Photographer for Event', 0.16320722021464462),
#  ('Event Photographer ', 0.16320722021464462),
#  ('Bak-Tang-Wiesenfeld Model Appl.', 0.16316934049370957),
#  ('Fujifilm Instax Mini Camera 25', 0.16310764000581912),
#  ('Looking For Goldendoodle', 0.16308333464485258),
#  ('Companionship', 0.16285855359151213),
#  ('Smash 64 Practice', 0.16064017102371508),
#  ('cloth', 0.16029411808585792),
#  ('Kazoo Concert', 0.15933896120810687),
#  ('PoGo Walker', 0.15854133863263087),
#  ('College night discount card', 0.15834429053859367),
#  ('Rhino Help', 0.15812741396773333),
#  ('Resume Building', 0.15692058656924246),
#  ('Rides to the Station', 0.15673574920538158),
#  ('Chillin', 0.15668958336527794),
#  ('Haircuts for men and women ', 0.15474674237702857),
#  ('Personal Advice ', 0.15378175354319978),
#  ('Fantasy Football Consulting', 0.15319935560000886),
#  ('Wisdom', 0.15277589754268206),
#  ('Programming', 0.15274996692778586),
#  ('Adobe Photoshop Help', 0.1519870108941177),
#  ('Wholesome memes', 0.15171597748337717),
#  ('CVS Picker Upper', 0.15141468250567414),
#  ('Wagner Discussion', 0.15042988658186118),
#  ('Ladies Burgundy Moto Jacket', 0.15039426958529134),
#  ('Artwork', 0.14928510427032016),
#  ('Power Drill ', 0.1490080656108148),
#  ('Overwatch coach', 0.14869346500597658),
#  ('Blueno Scarves', 0.14864071222012853),
#  ('Tattoo design ', 0.14844506927647672),
#  ('Family portrait', 0.14805154227792627),
#  ('Tinder profile honest review', 0.14799281351849913),
#  ('Date with my friend Ronan', 0.14578062773870215),
#  ('Investment Advice ', 0.1453412610471787),
#  ('Personal Cheerleader', 0.1448740924917047),
#  ('Increase Your Gym Gains', 0.14468420073558264),
#  ('Website Designer Needed', 0.1446725563075688),
#  ('3 Head Lamp', 0.14444431008575975),
#  ('App Development Consultant', 0.1439350686736134),
#  ('Photographer ', 0.14336963299319905),
#  ('Photographer', 0.14336963299319905),
#  ('BONEYARDS', 0.1431081347645886),
#  ('Seasonal Photos', 0.1427147860479181),
#  ('/competitively priced/ meme photoshop', 0.1423978405083517),
#  ('Will Venmo 1 dollar for insta follow', 0.14229348094204397),
#  ('Bike Fixing', 0.14189006187211817),
#  ('Egg the Carey bell tower', 0.1417506176912866),
#  ('Video Editor', 0.14153685818109807),
#  ('Jam session ', 0.14123125481197008),
#  ('Custom ArtWork', 0.14113883426907137),
#  ('COD Editor', 0.14107540342729408),
#  ('Cellist', 0.1409351453684735),
#  ('Rap Performer ', 0.14000052527990192),
#  ('Weekly Movie Recommendations', 0.13982431725293054),
#  ('Beautycounter Social', 0.13971854085650648),
#  ('Meme Advice', 0.13933452589537865),
#  ('RESOLVED: Andrew Canino’s Soul', 0.1393253828542811),
#  ('GRADUATION PHOTOS!', 0.1391532254208414),
#  ('Magic power', 0.1388089057192019),
#  ('Melee practice partner', 0.13820885127552174),
#  ('Melee Practice Partner', 0.13820885127552174),
#  ('Stickers needed', 0.1378766225213326),
#  ('LED Task Lamp', 0.13762270744632588),
#  ('Cup', 0.13729189007563036),
#  ('Wine Recommendations ', 0.1360365970284647),
#  ('Run aux at your function', 0.13551186966901696),
#  ('Put up posters', 0.13532403760041234),
#  ('ID Friend', 0.13525578474536815),
#  ('Looking For Printer', 0.13519393367391785),
#  ('Wedding', 0.13487003833415656),
#  ('Lamp ', 0.13380903229062824),
#  ('Prototype needed', 0.13306378525680884),
#  ('Need To Print Spring Weekend Ticket?', 0.13255842615353686),
#  ('Portrait Paintings ', 0.13228661943469433),
#  ('HTML email deisgn', 0.132231518208755),
#  ('Holiday Cocktail Party! ', 0.13158133595925392),
#  ('raf simons ', 0.13150461571080996),
#  ('Furniture mover!', 0.13027419183345046),
#  ('Furniture Mover', 0.13027419183345046),
#  ('Jingles and beats', 0.13013889376111365),
#  ('Personal driver', 0.12959383521251766),
#  ('Designing your website', 0.12920973184623108),
#  ('Smash 4 Games After Thxgiving', 0.12840309642015768),
#  ('Selling Galaxy Note 2', 0.12805062931136035),
#  ('The Economist Notebook', 0.12734232618652186),
#  ('Economist Notebook', 0.12734232618652186),
#  ('Gel nail', 0.12692124132945537),
#  ('Startup Opportunity', 0.12663586737221522),
#  ('Melee Practice', 0.12654908070226156),
#  ('Self portrait', 0.12591167184422147),
#  ('League of Legend partner', 0.12523489541183608),
#  ('Your man ', 0.12509528893656352),
#  ('Place more flyers #2!', 0.12474671288481431),
#  ('Place flyers #2 ', 0.12474671288481431),
#  ('Design The Coolest Debit Card For Kids/Teens', 0.12472936782125998),
#  ('Printer', 0.12464624926133183),
#  ('Logo Help ', 0.12463218238099216),
#  ('Portraits!', 0.12460149112524732),
#  ('Portraits', 0.12460149112524732),
#  ('LinkedIn Photoshoot', 0.12430803972239346),
#  ('TV', 0.1239422711056477),
#  ('Lifting Advice', 0.12312244697682218),
#  ('Personal shopper ', 0.12236451954959193),
#  ('Moving items', 0.12118656906181968),
#  ('apt cleaner', 0.12053469807235828),
#  ('Beats Studio Wireless', 0.12049384429576548),
#  ('Dachshund Breeder', 0.1204519723262365),
#  ('Anime Recommendations', 0.12042474050190322),
#  ('Thick Booty', 0.11952177154535093),
#  ('Tennis Racket', 0.11932148844232415),
#  ('Driver', 0.11849164265072432),
#  ('Change Lower Control Arms to Car', 0.1182768104661136),
#  ('Editing', 0.11746128071217754),
#  ('Wordpress and PHP developer', 0.11689278218682375),
#  ('Smash 4 Partner', 0.11579248992006796),
#  ('Solidworks Help', 0.11563179721707684),
#  ('SolidWorks help', 0.11563179721707684),
#  ('Iron', 0.11515853798823628),
#  ('Design', 0.1150355992419918),
#  ('Pool at GCB', 0.11287302722689674),
#  ('Frat Bylaws Review', 0.11273643960339541),
#  ('Foam modeling', 0.11242945625917855),
#  ('Social Media content creator', 0.11112062161089398),
#  ('Japanese Tutoring🇯🇵', 0.11102446336576577),
#  ('Consulting Cases', 0.11022152609797331),
#  ('Lots of photo gear!', 0.10945594017948679),
#  ('Looking For Graphic Design ', 0.10934789462021399),
#  ('Pokemon', 0.10909283584885543),
#  ('Pokemon ', 0.10909283584885543),
#  ('Rest. Review Partner', 0.10885511549145122),
#  ('Answers re: Pangea', 0.10734378172878678),
#  ('Ps4 Controller', 0.10715089399590738),
#  ('Alarm Clock / Clock', 0.10709715864800273),
#  ('Fashion designer ', 0.10579492008946545),
#  ('3D Print On A Form2 Printer', 0.10538912266974876),
#  ('Hand stitched coasters', 0.10527704808578164),
#  ('Running Partner', 0.10475814669257488),
#  ('Haircut', 0.1038528866025672),
#  ('Head shots', 0.10241886695455094),
#  ('Translation', 0.10170213011360829),
#  ('Editorial Photographer', 0.10168044882493632),
#  ('Hi', 0.10100945405730499),
#  ('Free Will', 0.10037504919961293),
#  ('Social Media Management ', 0.10033696475592535),
#  ('Social Media Management', 0.10033696475592535),
#  ('Friends In Ohio', 0.10002347430207692),
#  ('League of Legends Booster', 0.09984977311410148),
#  ('Steve Madden Heel Booties', 0.09954812229057097),
#  ('Mouse', 0.09944291070860345),
#  ('Paper Models', 0.09899152726347893),
#  ('Poster design', 0.09889967253445775),
#  ('Poster Design', 0.09889967253445775),
#  ('TV Screen', 0.09811879452536232),
#  ('League of Legends', 0.0978454254757608),
#  ('An Oil Portrait', 0.09778479041429478),
#  ('Chromosomes', 0.09612266873216413),
#  ('Social Media Marketing Consultation', 0.0957117692933025),
#  ('Graphic Design ', 0.09471814502808229),
#  ('Website Design', 0.09450215708773158),
#  ('Research', 0.09445039554248069),
#  ('Marketing', 0.09373878139990666),
#  ('Social Media Marketing ', 0.09370607944897813),
#  ('Business Card Creation', 0.09313214017674909),
#  ('Chiropractor', 0.09304197381135282),
#  ('Looking for Team member', 0.09174565455668926),
#  ('Cvs', 0.09147907908491959),
#  ('Startup Opportunities', 0.091421240895599),
#  ('Test Post', 0.09139273060327469),
#  ('Graphic designer ', 0.09012730927236134),
#  ('Graphic Designer', 0.09012730927236134),
#  ('Graphic Designer ', 0.09012730927236134),
#  ('Looking for group', 0.0897388401143644),
#  ('SNAPSTREAK REMINDERS 🔥', 0.08801286349927295),
#  ('Instagenic Photoshoot + Photoshop!', 0.08748212030104696),
#  ('Looking For Factorio Players', 0.0844087617463174),
#  ('My thoughts ', 0.0836172618185742),
#  ('Web development and design', 0.08330747294928642),
#  ('Video Production ', 0.08319603946844722),
#  ('Puma Shoes & Jordan 2’s', 0.08294167003487019),
#  ('Feedback (re: Pangea)', 0.08285626640827104),
#  ('Word2vec model ', 0.08186586755937242),
#  ('Pangea Post Consulting ', 0.08172903519880492),
#  ('Sneaker Shopping ', 0.08143883444438416),
#  ('cs hw ', 0.08053977401812062),
#  ('Photoshoot', 0.08017804937378514),
#  ('A Dev', 0.07780689716344114),
#  ('Ethernet Cable', 0.07580081395144589),
#  ('funding for CSA', 0.07362688610572832),
#  ('IG Social media marketing', 0.07265462481279883),
#  ('Foam Models', 0.0724122158791829),
#  ('Drawing', 0.07214716976648106),
#  ('2k', 0.07049219836176235),
#  ('Parking Spot', 0.07038693791838568),
#  ('Astrological Consultations', 0.06924217520327147),
#  ('Goals ', 0.06826516194632859),
#  ('Headshot/Linkedin Photos', 0.06681198524324827),
#  ('Prototype', 0.066272745005449),
#  ('Black Ops/Fortnite Teammate ', 0.06620638257061273),
#  ('Meme Photoshop', 0.06476925590061455),
#  ('Paracord Bracelet', 0.06149738396754856),
#  ('Moving', 0.06055371333599169),
#  ('Search Engine Optimizatio', 0.057226123884220215),
#  ('Photoshop', 0.056800956623646925),
#  ('Melee', 0.054491582788159576),
#  ('Melee tutorring', 0.054491582788159576),
#  ('Original Prints', 0.05381984084817759),
#  ('Late night Jo’s delivery', 0.05340303411446712),
#  ('Meme maker', 0.052461275389759976),
#  ('Shirt', 0.051710531437493046),
#  ('Galaxy s7 edge', 0.05018324827392462),
#  ('Developer and UI/UX Designer', 0.050040471455986335),
#  ('Quick ************ 2d / 3d', 0.04981080288166595),
#  ('Postering', 0.04386523417861099),
#  ('Logo design', 0.0424103478253528),
#  ('Logo Design', 0.0424103478253528),
#  ('Financial Services ', 0.04166018211009259),
#  ('Motion Graphics Designer/Animator', 0.038313198847390595),
#  ('Web Development', 0.038161798046985496),
#  ('Web development ', 0.038161798046985496),
#  ('Bo4 Teammate', 0.0319544602493238),
#  ('Blue chair', 0.029858912828331086),
#  ('iPhone 6\\6s Screen Replacement', 0.028006038822411483),
#  ('Amazon Echo', 0.024275512499343677),
#  ('Fan', 0.020109126011902845),
#  ('Removal of Waterbed ', 0.019100719043649406),
#  ('Motion graphic', 0.018890255795213307),
#  ('Pharmacology/Medication Reviews', 0.015365264951839208),
#  ('Metal machine ', 0.013168021839021549),
#  ('Promotional Memes', 0.013001204855299875),
#  ('Web Developer', 0.011461063492333778),
#  ('Web developer ', 0.011461063492333778),
#  ('Website developer', 0.008464186396395235),
#  ('Image to vector conversion', 0.007716420627730258),
#  ('Python 101', 0.007125029471353628),
#  ('Headshots', 0.006138601473139715),
#  ('Pattern maker', 0.00586278074325719),
#  ('Bottle Caps', 0.0032776426619847143),
#  ('Diamond snapback ', 0.0029704889100230503),
#  ('Designer/photographer/brand ID', 0.0025424922814636375),
#  ('INSTAGRAM', 0.0),
#  ('Petsitting', 0.0),
#  ('Proofreading/Editing', 0.0),
#  ('Dogsitter', 0.0),
#  ('Dogsitting And Catsitting ', 0.0),
#  ('SCRIPPS', 0.0),
#  ('Programmer/Consultant', 0.0),
#  ('Jeenne', 0.0),
#  ('Dogsitting', 0.0),
#  ('Dogwalking', 0.0),
#  ('Full-Stack Developer', -0.014353943776086453),
#  ('Back-end Developer', -0.01473581306709093),
#  ('RemoveSeniorPic Watermark', -0.07397262892087042)]

# %%
'''Load the current titles in the Pangea database, and then rank them by similarity to the latest user query'''
def rank_existing_titles(vectorized_title):
    ranked_titles = {}
    other_titles = pd.read_pickle("./vectorized_titles.pkl")
    #print(other_titles)
    for index,row in other_titles.iterrows():
        ranked_titles[row['Titles']] = sum((row['Vectors'][0])*(vectorized_title.iloc[1, 0:].values)) 
    #sorted_title_vecs = sorted(ranked_titles.items(), key=operator.itemgetter(1), reverse=True)
    #sorted_title_vecs = sorted_title_vecs.all()
    #return(sorted_title_vecs.all())
    return(other_titles)

#should this also be named ranked titles? or should we rename this line? since we're 
#already loading them in the cell above ??
rank_existing_titles(vectorized_title)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-70-bdcf529bf8a2> in <module>
#      13 #should this also be named ranked titles? or should we rename this line? since we're
#      14 #already loading them in the cell above ??
# ---> 15 rank_existing_titles(vectorized_title)
#
# <ipython-input-70-bdcf529bf8a2> in rank_existing_titles(vectorized_title)
#       5     #print(other_titles)
#       6     for index,row in other_titles.iterrows():
# ----> 7         ranked_titles[row['Titles']] = sum((row['Vectors'][0])*(vectorized_title.iloc[1, 0:].values))
#       8     #sorted_title_vecs = sorted(ranked_titles.items(), key=operator.itemgetter(1), reverse=True)
#       9     #sorted_title_vecs = sorted_title_vecs.all()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2011     def _getitem_tuple(self, tup):
#    2012
# -> 2013         self._has_valid_tuple(tup)
#    2014         try:
#    2015             return self._getitem_lowerdim(tup)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     220                 raise IndexingError('Too many indexers')
#     221             try:
# --> 222                 self._validate_key(k, i)
#     223             except ValueError:
#     224                 raise ValueError("Location based indexing can only have "
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1955             return
#    1956         elif is_integer(key):
# -> 1957             self._validate_integer(key, axis)
#    1958         elif isinstance(key, tuple):
#    1959             # a tuple should already have been caught by this point
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
#vectorized_title.loc[0]
vectorized_title.loc[0][1]
#vectorized_title.loc['Vector'][0][0]
#other_titles = pd.read_pickle("./vectorized_titles.pkl")
#type(other_titles['Vectors'][0])
# Out:
# array([[-2.29741372e-02,  1.05010541e-02,  5.97524792e-02,
#          4.16098125e-02,  2.97776368e-02,  1.00179069e-01,
#          6.07384928e-02, -4.60468754e-02, -8.77552852e-02,
#         -3.14045623e-02,  5.07797450e-02, -1.04517536e-02,
#          9.86014493e-05,  4.02170643e-02, -4.64412831e-02,
#          1.07278377e-01, -2.32699420e-02,  2.42559556e-02,
#         -2.31713406e-03, -5.24559692e-02,  9.70238224e-02,
#          5.40335923e-02,  1.34492382e-01,  4.77724001e-02,
#         -1.77482609e-02, -7.41482899e-02, -8.57370382e-04,
#         -3.94405797e-02, -7.93741643e-02, -2.45517604e-02,
#          5.91608696e-04,  3.44119072e-02, -7.96699673e-02,
#         -3.74685489e-02, -2.57842783e-02, -1.47778923e-02,
#          8.80264416e-02, -2.21113749e-02, -8.28252174e-03,
#          1.87342754e-03,  9.33016185e-03, -3.51021141e-02,
#          8.22336078e-02, -6.16259035e-03, -3.43626030e-02,
#         -3.66797373e-02, -1.09250404e-01,  1.01806000e-02,
#         -2.78425831e-02,  4.56524715e-02, -8.31210241e-02,
#         -7.00070290e-03,  3.44119072e-02, -5.03853410e-02,
#         -1.01158926e-02, -6.73201382e-02,  5.42800985e-02,
#         -6.47811517e-02, -6.25133216e-02, -4.82284352e-02,
#          6.57671690e-02,  8.67692754e-03, -5.01881354e-02,
#         -8.47972464e-03,  7.75007382e-02, -5.13713546e-02,
#         -6.48797527e-02,  6.50769565e-03,  2.21360251e-02,
#          6.50769565e-03,  7.11162910e-02,  4.95965295e-02,
#          2.38738749e-02,  5.65972328e-02,  2.77070068e-02,
#         -8.73608813e-02, -5.74846454e-02,  1.57330930e-02,
#          2.16923188e-03, -6.60629710e-03,  4.66631353e-02,
#         -2.31713406e-03,  2.95804348e-03,  5.44280000e-02,
#         -4.16837633e-02,  3.85531671e-02, -7.75007382e-02,
#          1.18321739e-01, -2.47982647e-02, -1.09940618e-02,
#         -1.56160044e-02, -4.62933816e-02, -1.24632232e-01,
#         -4.76984493e-02,  5.85692599e-02, -5.78790493e-02,
#          6.11328967e-02, -7.16832504e-02,  4.33353372e-02,
#         -5.56112155e-02, -8.05573836e-02, -4.78217006e-02,
#          8.67692754e-03,  2.87176725e-02,  6.65559759e-03,
#         -9.69252214e-02,  1.24237826e-02, -4.65398841e-02,
#          6.25133216e-02, -2.40587536e-02, -7.95713663e-02,
#         -2.22839266e-02, -5.54140136e-02, -3.97363827e-02,
#          9.12679639e-03,  2.41080541e-02,  3.72220464e-02,
#         -5.47731034e-02, -5.09769469e-02, -2.30727382e-02,
#         -3.62360314e-03,  3.18482667e-02,  3.68276425e-02,
#          7.67119303e-02, -1.08954599e-02,  1.71566512e-02,
#         -1.00967884e-01, -5.71888406e-03,  0.00000000e+00,
#          7.80923441e-02,  4.53566667e-03, -3.35244909e-02,
#          5.52168116e-03,  4.97937314e-02,  4.80189063e-02,
#          6.51755556e-02,  4.41734493e-02, -3.00734416e-02,
#          3.41900513e-02,  2.19634734e-02, -2.35164445e-02,
#         -6.51755556e-02, -2.62279846e-02, -9.18965489e-02,
#         -6.05412908e-02,  4.47650589e-02, -4.64412831e-02,
#         -2.44531594e-02, -4.83147101e-03, -7.98671767e-02,
#          2.11007092e-02, -1.31632937e-02, -6.49783537e-02,
#          8.83468986e-02, -7.82895535e-02, -5.02867391e-03,
#         -6.47811517e-02, -8.87413025e-02, -1.09349005e-01,
#         -4.25958261e-02,  5.07304445e-02,  1.02742709e-01,
#         -5.25545701e-02, -2.48475652e-02,  5.08783460e-02,
#          3.37216966e-02,  7.47398958e-02, -5.74784800e-02,
#          1.53029442e-01, -5.27517758e-02, -1.22660205e-01,
#          3.13552618e-02,  1.41986087e-02,  4.40748483e-02,
#          5.89636676e-02,  4.23493236e-02,  7.69091323e-02,
#          4.02293913e-02, -1.09447604e-02,  1.84261464e-02,
#         -4.33846377e-02, -5.35405874e-02,  5.64986281e-02,
#         -5.64493276e-02, -2.07802560e-02, -2.73126010e-02,
#         -4.82161082e-02, -7.61203170e-02,  3.56937237e-02,
#          1.90115925e-02,  1.77482609e-03, -2.71153986e-03,
#          4.24725749e-02,  4.76244986e-02, -1.27688879e-02,
#          2.16923188e-02,  8.05573836e-02, -5.49148433e-02,
#         -8.97273198e-02, -2.88902242e-02, -7.07958415e-02,
#         -4.05991450e-02, -4.35571894e-02, -1.39028039e-02,
#         -1.54015467e-01, -7.96699673e-02, -8.40084329e-02,
#         -1.25840101e-02, -5.80207892e-02, -7.55287111e-02,
#         -8.81496966e-02,  6.40909448e-02,  3.05664483e-02,
#         -1.47409169e-02,  6.07384928e-02,  6.92182183e-02,
#          9.46573913e-03,  2.30727382e-02, -3.75671536e-02,
#         -7.47398958e-02,  5.52168116e-02,  3.59648764e-02,
#          1.06292360e-01, -7.29650725e-03,  6.38937354e-02,
#         -2.08049063e-02,  7.48384967e-02, -2.36027222e-03,
#         -3.61127802e-03, -8.73608813e-02,  5.91608696e-02,
#         -5.53647131e-02,  1.66389942e-02,  1.09940618e-02,
#          1.56579107e-01, -1.01362288e-01,  1.16744116e-01,
#         -2.22407896e-02, -9.25867632e-02, -2.26783324e-02,
#         -4.63426821e-02,  3.17496657e-02,  2.32206415e-02,
#         -2.95188092e-03, -1.13588870e-01, -6.21189140e-02,
#         -6.73940927e-02, -2.72140000e-02,  2.64498387e-02,
#         -1.10039219e-01, -2.93339300e-03,  5.22587672e-02,
#         -2.62279846e-02,  5.84706590e-02,  1.04714736e-01,
#         -2.33438928e-02, -7.69091323e-02, -1.47902174e-02,
#         -5.09276465e-02, -1.12775406e-02,  9.26853623e-03,
#         -5.62028261e-03, -8.88399035e-02, -9.18965489e-02,
#         -4.63426812e-03,  1.97202899e-03,  1.53818261e-02,
#         -7.49371015e-03, -5.96538745e-03,  1.77482609e-03,
#          6.31049275e-02,  2.35041194e-02, -1.77482609e-03,
#          2.80028116e-02,  5.36391884e-02, -7.82402456e-02,
#         -4.16591130e-02, -4.56524715e-02, -1.24829434e-01,
#         -1.28181890e-01,  7.69091323e-02, -2.56117266e-02,
#          5.77804483e-02,  6.72461912e-02,  2.06570029e-02,
#         -5.23573682e-02, -6.49783537e-02,  7.84867555e-02,
#         -5.96538745e-02,  1.77482605e-01, -1.94244850e-02,
#          5.14699556e-02, -1.37450412e-01,  3.13552618e-02,
#         -6.20203093e-02, -5.32447807e-02, -7.02535314e-03,
#         -7.55287111e-02,  7.98671767e-02,  5.48224039e-02]], dtype=float32)

# %%
'''Final function call API that puts together the prior 3 functions in a neat mega-function'''
def generate_recommendations(user_post):
    title = user_post["title"]
    vectorized_title = vectorize_new_title(user_post)
    #ranked_titles = rank_existing_titles(vectorized_title) 
    #pprint(ranked_titles)
    ranked_titles = pd.DataFrame(rank_existing_titles(vectorized_title), columns = ["Title", "Similarity Score"])
    with open("./ranked_titles.csv", "w", newline='') as myfile:
        wr = csv.writer(myfile,  delimiter=',', quoting=csv.QUOTE_ALL)
        for title in ranked_titles:
            #wr.writerow([ranked_titles, title])
            wr.writerow([ranked_titles])
    return(ranked_titles)

#should this still be ranked titles.csv???

# %%
#sanity check for final mega function
generate_recommendations(user_post)
# Out:
#                                  Title  Similarity Score
# 0                Teach Me How To Cook!          1.000000
# 1    Teach me how to cook quick meals!          0.850110
# 2         Teach how to prepare steaks           0.743369
# 3                        Private Cook           0.717745
# 4                         Private cook          0.717745
# 5                      Cooking Lessons          0.670795
# 6                      Cooking lessons          0.670795
# 7                     Cooking Lessons           0.670795
# 8                              Cooking          0.663496
# 9           Teach me how to play piano          0.647565
# 10               Teach how to make tea          0.629968
# 11                      Culinary tutor          0.593930
# 12                     Baking Lessons           0.582271
# 13         Mediterranean Cooking Class          0.570201
# 14            Teach you how to shuffle          0.569913
# 15   Teach Me How To Solve Rubiks Cube          0.556002
# 16             Brazilian Cooking Class          0.549136
# 17                    Learn To Juggle!          0.535593
# 18             Chef Prepared Meal Prep          0.532709
# 19       Help me learn Pop/Stars dance          0.510932
# 20               Teach me meme culture          0.504013
# 21                Pretend Dad for Hire          0.494830
# 22                    Rice Cooking Pot          0.487511
# 23                          Math Tutor          0.485789
# 24                          Math tutor          0.485789
# 25                      Splatoon Tutor          0.468270
# 26                     Mariokart tutor          0.468270
# 27                          Mk8 Tutor           0.468270
# 28                         Sm4sh Tutor          0.468270
# 29       Piano classes (for beginners)          0.458619
# ..                                 ...               ...
# 711                        Amazon Echo          0.024276
# 712                                Fan          0.020109
# 713               Removal of Waterbed           0.019101
# 714                     Motion graphic          0.018890
# 715    Pharmacology/Medication Reviews          0.015365
# 716                     Metal machine           0.013168
# 717                  Promotional Memes          0.013001
# 718                      Web Developer          0.011461
# 719                     Web developer           0.011461
# 720                  Website developer          0.008464
# 721         Image to vector conversion          0.007716
# 722                         Python 101          0.007125
# 723                          Headshots          0.006139
# 724                      Pattern maker          0.005863
# 725                        Bottle Caps          0.003278
# 726                  Diamond snapback           0.002970
# 727     Designer/photographer/brand ID          0.002542
# 728                         Dogsitting          0.000000
# 729                          Dogsitter          0.000000
# 730              Programmer/Consultant          0.000000
# 731               Proofreading/Editing          0.000000
# 732                          INSTAGRAM          0.000000
# 733                         Petsitting          0.000000
# 734         Dogsitting And Catsitting           0.000000
# 735                            SCRIPPS          0.000000
# 736                         Dogwalking          0.000000
# 737                             Jeenne          0.000000
# 738               Full-Stack Developer         -0.014354
# 739                 Back-end Developer         -0.014736
# 740          RemoveSeniorPic Watermark         -0.073973
#
# [741 rows x 2 columns]

# %%
#sanity check
df = pd.DataFrame(generate_recommendations(user_post))
df.columns = ["Title", "Similarity Score"]
print(df)
# Out:
#                                  Title  Similarity Score
# 0                Teach Me How To Cook!          1.000000
# 1    Teach me how to cook quick meals!          0.850110
# 2         Teach how to prepare steaks           0.743369
# 3                        Private Cook           0.717745
# 4                         Private cook          0.717745
# 5                      Cooking Lessons          0.670795
# 6                      Cooking lessons          0.670795
# 7                     Cooking Lessons           0.670795
# 8                              Cooking          0.663496
# 9           Teach me how to play piano          0.647565
# 10               Teach how to make tea          0.629968
# 11                      Culinary tutor          0.593930
# 12                     Baking Lessons           0.582271
# 13         Mediterranean Cooking Class          0.570201
# 14            Teach you how to shuffle          0.569913
# 15   Teach Me How To Solve Rubiks Cube          0.556002
# 16             Brazilian Cooking Class          0.549136
# 17                    Learn To Juggle!          0.535593
# 18             Chef Prepared Meal Prep          0.532709
# 19       Help me learn Pop/Stars dance          0.510932
# 20               Teach me meme culture          0.504013
# 21                Pretend Dad for Hire          0.494830
# 22                    Rice Cooking Pot          0.487511
# 23                          Math Tutor          0.485789
# 24                          Math tutor          0.485789
# 25                      Splatoon Tutor          0.468270
# 26                     Mariokart tutor          0.468270
# 27                          Mk8 Tutor           0.468270
# 28                         Sm4sh Tutor          0.468270
# 29       Piano classes (for beginners)          0.458619
# ..                                 ...               ...
# 711                        Amazon Echo          0.024276
# 712                                Fan          0.020109
# 713               Removal of Waterbed           0.019101
# 714                     Motion graphic          0.018890
# 715    Pharmacology/Medication Reviews          0.015365
# 716                     Metal machine           0.013168
# 717                  Promotional Memes          0.013001
# 718                      Web Developer          0.011461
# 719                     Web developer           0.011461
# 720                  Website developer          0.008464
# 721         Image to vector conversion          0.007716
# 722                         Python 101          0.007125
# 723                          Headshots          0.006139
# 724                      Pattern maker          0.005863
# 725                        Bottle Caps          0.003278
# 726                  Diamond snapback           0.002970
# 727     Designer/photographer/brand ID          0.002542
# 728                         Dogsitting          0.000000
# 729                          Dogsitter          0.000000
# 730              Programmer/Consultant          0.000000
# 731               Proofreading/Editing          0.000000
# 732                          INSTAGRAM          0.000000
# 733                         Petsitting          0.000000
# 734         Dogsitting And Catsitting           0.000000
# 735                            SCRIPPS          0.000000
# 736                         Dogwalking          0.000000
# 737                             Jeenne          0.000000
# 738               Full-Stack Developer         -0.014354
# 739                 Back-end Developer         -0.014736
# 740          RemoveSeniorPic Watermark         -0.073973
#
# [741 rows x 2 columns]

# %%
other_titles = pd.read_pickle("./vectorized_titles.pkl")

# %%
other_titles
# Out:
#                                                 Titles  \
# 0                                   Waterpolo Tutoring
# 1    Eliminate Russell Carey & Replace Him With a R...
# 2                     Bosnian/Croatian Language Tutor
# 3                                  Portrait Paintings
# 4                                   GRADUATION PHOTOS!
# 5                                 Need Help In History
# 6                                    tennis stringing
# 7                                   Personal organizer
# 8                                            Cs tutor
# 9                                 Rides to the Station
# 10                                         Moving Help
# 11                                       Essay Editing
# 12                                           Whatever
# 13                                    Marketing Advice
# 14                                             Car wax
# 15                                Rest. Review Partner
# 16                          Quick ************ 2d / 3d
# 17                                         Bike Fixing
# 18                     Prototyping/Wireframing Lessons
# 19                Will Venmo 1 dollar for insta follow
# 20                                          Python 101
# 21                               Set me up with a boy
# 22                                             cuddler
# 23                                   Personal shopper
# 24                   Guinea Pig Thanksgiving Petsitter
# 25                                   Paracord Bracelet
# 26                              Dog Sitting / Walking
# 27                                      I'll be friend
# 28                                Financial Accountant
# 29                                   Website developer
# ..                                                 ...
# 711                                       Workout Plan
# 712                                    Art Commissions
# 713                                       Blog writer
# 714                                     Galaxy s7 edge
# 715                                        Photography
# 716                                      Homework help
# 717                                    Resume Building
# 718                       Teach how to prepare steaks
# 719                                hang up my TV mount
# 720                                     Rap Performer
# 721                                Breakdance sessions
# 722                                     Food delivery!
# 723                                        Work wanted
# 724                     iPhone 6\6s Screen Replacement
# 725                         Lessons On App Prototyping
# 726                                     Shopping buddy
# 727             Spanish tutoring/conversation practice
# 728                       Bate Papo/Portuguese Lessons
# 729                                   Sketch tutorials
# 730                              Feedback (re: Pangea)
# 731                                          Squirrels
# 732                 Instagenic Photoshoot + Photoshop!
# 733                                     Research Buddy
# 734                                             Design
# 735                                             Driver
# 736                                    Friends In Ohio
# 737                                  Sneaker Shopping
# 738                                basic guitar chords
# 739                                    Ukulele Lessons
# 740                                  Smash 64 Practice
#
#                                                Vectors
# 0    [[0.004673245, 0.06561235, 0.028039468, 0.0306...
# 1    [[-0.04523085, 0.047022626, 0.030563282, 0.070...
# 2    [[0.01473858, -0.013819061, 0.02217355, 0.0680...
# 3    [[0.078219034, 0.06146943, -0.020530464, 0.031...
# 4    [[-0.020564673, 0.12495787, -0.04615278, 0.043...
# 5    [[0.034072954, 0.067304604, 0.025347782, 0.039...
# 6    [[-0.07873873, 0.025344653, -0.0038067068, 0.0...
# 7    [[0.09288177, -0.03567334, 0.038201373, -0.036...
# 8    [[-0.026808849, 0.018503362, 0.04615327, 0.039...
# 9    [[-0.010272413, 0.016525187, 0.010942353, 0.02...
# 10   [[-0.0073657073, 0.09981285, -0.044419724, 0.0...
# 11   [[0.025215803, 0.011204577, -0.036277294, -0.0...
# 12   [[0.043075226, -0.060968015, 0.0037000517, 0.0...
# 13   [[0.01688988, -0.03561996, -0.05343707, -0.020...
# 14   [[0.04384796, 0.083078854, 0.0006514878, -0.02...
# 15   [[-0.11095869, -0.07103768, -0.017367447, 0.07...
# 16   [[0.153939, 0.037689175, -0.018424498, 0.12967...
# 17   [[-0.06293868, 2.605078e-05, 0.013129593, 0.01...
# 18   [[0.053415272, 0.037238076, 0.07935984, -0.027...
# 19   [[-0.061780103, -0.09158573, 0.004569285, 0.11...
# 20   [[0.07310092, 0.032689493, -0.107592195, 0.041...
# 21   [[0.0746951, 0.11978754, 0.08082217, -0.011428...
# 22   [[-0.03970707, -0.0076992977, -0.039319683, 0....
# 23   [[0.116019934, 0.055707566, -0.08892039, 0.081...
# 24   [[-0.012972425, -0.037378173, -0.012349456, 0....
# 25   [[-0.05443361, -0.11862419, -0.0069325822, 0.1...
# 26   [[0.08265024, 0.03933478, -0.033404812, 0.1129...
# 27   [[0.015295482, -0.031769928, -0.025813065, 0.0...
# 28   [[0.049372848, -0.056639846, -0.07673096, -0.0...
# 29   [[0.07557175, -0.12713984, -0.007888867, -0.10...
# ..                                                 ...
# 711  [[-0.005178752, 0.105007455, 0.038785547, 0.03...
# 712  [[0.013669117, 0.010003179, 0.049483057, 0.088...
# 713  [[0.023989394, -0.02488783, -0.065154076, 0.03...
# 714  [[0.026702164, 0.027555289, 0.0004981747, -0.0...
# 715  [[0.0005714418, 0.017823197, -0.026233276, 0.0...
# 716  [[-0.011092936, 0.035716817, -0.008959679, 0.0...
# 717  [[-0.035966646, 0.055128187, 0.020804845, 0.01...
# 718  [[-0.019265316, 0.05949351, 0.033734042, 0.022...
# 719  [[-0.044453368, 0.044327557, -0.11491825, 0.04...
# 720  [[0.027135165, 0.044441022, 0.008313085, 0.012...
# 721  [[-0.004240162, 0.031446796, -0.0024745017, 0....
# 722  [[-0.064729154, 0.06401915, -0.060705774, 0.12...
# 723  [[0.009062805, 0.07995733, 0.0551077, 0.010816...
# 724  [[-0.076713264, -0.026213985, -0.035564583, 0....
# 725  [[0.020253977, -0.031405043, -0.050369438, 0.0...
# 726  [[0.038141776, 0.02493247, -0.04317011, 0.1375...
# 727  [[-0.025693027, -0.051538784, -0.004831761, 0....
# 728  [[0.05909906, 0.089635506, 0.0881261, 0.029143...
# 729  [[0.00069486385, 9.926626e-05, 0.022384543, 0....
# 730  [[-0.06494846, -0.00715124, -0.04504936, -0.04...
# 731  [[-0.058443204, 0.030668216, -0.113993175, 0.0...
# 732  [[0.014065908, 0.027678078, -0.10299875, 0.044...
# 733  [[-0.033732753, -0.053159453, -0.0073673795, 0...
# 734  [[-0.078394495, -0.012321907, -0.0066460683, 0...
# 735  [[0.06738029, -0.09356434, -0.02496213, -0.078...
# 736  [[0.033710547, -0.014110273, 0.005923425, 0.15...
# 737  [[0.04779238, 0.051733505, -0.050037324, 0.114...
# 738  [[0.12965396, -0.08273698, -0.0038366285, 0.02...
# 739  [[0.061797857, -0.00044781057, 0.055618074, 0....
# 740  [[0.062727526, 0.018316587, -0.04743604, -0.00...
#
# [741 rows x 2 columns]
